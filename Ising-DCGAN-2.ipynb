# %% [markdown]
# <a href="https://colab.research.google.com/github/raeubaen/ml/blob/master/Ising-DCGAN-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import models & layers from TF/keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# tensor manipulation library
import numpy as np
# plotting library
import matplotlib.pyplot as plt

# plot style parameters
plt.style.use('ggplot')
plt.rcParams['axes.facecolor'] = '#f7f9fc'
from sklearn.model_selection import train_test_split

# %% [markdown]
# Scarico i file con configurazioni (10000 array 28x28) e temperature.

# %%
# dataset download
# !wget https://raw.githubusercontent.com/raeubaen/ml/master/dissertazione/conf.dat
# !wget http://www.roma1.infn.it/~giagu/datasets/ising2_label.dat

# reading configurations and temperatures into numpy 
# (10k elements with 28x28 spin configuration)
conf, temp = np.loadtxt('conf.dat'), np.loadtxt('ising2_label.dat')
# Out:
# --2020-08-20 21:38:37--  https://raw.githubusercontent.com/raeubaen/ml/master/dissertazione/conf.dat
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18782882 (18M) [text/plain]
# Saving to: ‘conf.dat’
#
# conf.dat            100%[===================>]  17.91M  88.1MB/s    in 0.2s
#
# 2020-08-20 21:38:40 (88.1 MB/s) - ‘conf.dat’ saved [18782882/18782882]
#
# --2020-08-20 21:38:41--  http://www.roma1.infn.it/~giagu/datasets/ising2_label.dat
# Resolving www.roma1.infn.it (www.roma1.infn.it)... 141.108.26.150, 141.108.26.1
# Connecting to www.roma1.infn.it (www.roma1.infn.it)|141.108.26.150|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 81025 (79K)
# Saving to: ‘ising2_label.dat’
#
# ising2_label.dat    100%[===================>]  79.13K  --.-KB/s    in 0.06s
#
# 2020-08-20 21:38:41 (1.39 MB/s) - ‘ising2_label.dat’ saved [81025/81025]

# %% [markdown]
# Le temperature verranno divise in 10 classi da 0.5 ciascuna e verranno codificate in vettori one-hot.

# %%
BATCH_SIZE = 64
IMG_SHAPE = (28, 28, 1)
NUM_TEMP_CLASSES = 10
LATENT_DIM = 128

# reshaping configurations into matrix form and specifying dtype
conf = conf.reshape(-1, *IMG_SHAPE).astype('float32')
label = (temp.reshape(-1, 1)*2).astype("int32")

one_hot_temp = keras.utils.to_categorical(label)

# %% [markdown]
# Inserisco i dati in un dataset Tensorflow.

# %%
# converting data (conf and temperatures) into tensorflow Dataset
dataset = tf.data.Dataset.from_tensor_slices((conf, one_hot_temp))
# shuffling and prefetching
dataset = dataset.shuffle(buffer_size=1024).batch(BATCH_SIZE).prefetch(32)

# %% [markdown]
# Costruisco il discriminatore, che prende in input gli array delle configurazioni ed il vettore one-hot che rappresenta la classe di temperatura.

# %%
def get_discriminator_model():

    temp_input = layers.Input(shape=(NUM_TEMP_CLASSES,), name="D_Temp_Input")

    t = layers.Dense(28*28, name="D_temp_Dense")(temp_input)
    t = layers.LeakyReLU(name="D_temp_LReLU")(t)
    t = layers.Reshape(IMG_SHAPE, name="D_temp_Reshape")(t)

    img_input = layers.Input(shape=IMG_SHAPE, name="D_Image_Input")
    x = layers.Concatenate(name="D_Concatenate")([t, img_input])

    x = layers.Conv2D(64, (5, 5), strides=(2, 2), padding='same', 
                      input_shape=IMG_SHAPE, name="D_Conv2D_1")(x)
    x = layers.LeakyReLU(name="D_LReLu_1")(x)
    x = layers.Dropout(0.3, name="D_DropOut_1")(x)

    x = layers.Conv2D(128, (5, 5), strides=(2, 2), 
                      padding='same', name="D_Conv2D_2")(x)
    x = layers.LeakyReLU(name="D_LReLu_2")(x)
    x = layers.Dropout(0.3, name="D_DropOut_2")(x)

    x = layers.Flatten(name="D_Final_Flatten")(x)
    x = layers.Dense(1, name="D_Final_Dense", activation="sigmoid")(x)

    model = keras.models.Model([img_input, temp_input], x, name="discriminator")
    return model

d_model = get_discriminator_model()

# %% [markdown]
# Definisco il generatore, che prende in input il vettore latente (di dimensione 128) e la classe di temperatura come one-hot.

# %%
def get_generator_model():

    temp_input = layers.Input(shape=(NUM_TEMP_CLASSES,), name="G_Temp_Input")

    latent_vector = layers.Input(shape=(LATENT_DIM,), name="G_Latent_Input")

    x = layers.Concatenate(name="G_Concatenate")([latent_vector, temp_input])

    x = layers.Dense(7*7*256, use_bias=False, 
                     input_shape=(2*LATENT_DIM,), name="G_Dense_1")(x)
    x = layers.BatchNormalization(name="G_BM_1")(x)
    x = layers.LeakyReLU(name="G_LReLU_1")(x)

    x = layers.Reshape((7, 7, 256), name="G_Reshape")(x)
    
    x = layers.Conv2DTranspose(128, (4, 4), strides=(1, 1), padding='same', 
                               use_bias=False, name="G_Conv2DTranspose_1")(x)
    x = layers.BatchNormalization(name="G_BM_2")(x)
    x = layers.LeakyReLU(name="G_LReLU_2")(x)

    x = layers.Conv2DTranspose(64, (4, 4), strides=(2, 2), padding='same', 
                               use_bias=False, name="G_Conv2DTranspose_2")(x)
    x = layers.BatchNormalization(name="G_BM_3")(x)
    x = layers.LeakyReLU(name="G_LReLU_3")(x)

    x = layers.Conv2DTranspose(1, (7, 7), strides=(2, 2), padding='same',
       use_bias=False, activation=tf.tanh, name="G_Final_Conv2DTranspose")(x)

    model = keras.models.Model([temp_input, latent_vector], x, name="generator")
    return model

g_model = get_generator_model()
print(g_model.count_params())
# Out:
# 2440512

# %% [markdown]
# Definisco ed alleno il regressore, che prende in input una configurazione e ne restituisce la classe di temperatura come one-hot.

# %%
def get_regressor_model():
  #modello da https://github.com/raeubaen/ml/blob/master/NB_CNN_LC3_2020.ipynb
  inputs = keras.Input(shape=(28,28,1))

  data_augmentation = keras.Sequential([
    keras.layers.experimental.preprocessing.RandomFlip()
  ], name='DataAugm')

  activation = "relu"

  x = data_augmentation(inputs)

  layer_with_activation = lambda name, x: \
      keras.layers.ReLU(name=name)(x)

  ks = 2
  f1 = 64
  x = keras.layers.Conv2D(f1, kernel_size=(ks,ks), name='Conv_1')(x)
  x = layer_with_activation(f'{activation}_1', x)
  x = keras.layers.MaxPooling2D((2,2), name='MaxPool_1')(x)
  x = keras.layers.Conv2D(f1, kernel_size=(ks,ks), name='Conv_2')(x)
  x = layer_with_activation(f'{activation}_2', x)
  x = keras.layers.MaxPooling2D((2,2), name='MaxPool_2')(x)

  x = keras.layers.Conv2D(f1, kernel_size=(ks,ks), name='Conv_3')(x)
  x = layer_with_activation(f'{activation}_3', x)

  x = keras.layers.Flatten(name='Flatten')(x)

  dense_n = 64
  x = keras.layers.Dense(dense_n, name='Dense_1')(x)
  x = layer_with_activation(f'{activation}_dense_1', x)
  x = keras.layers.Dense(dense_n, name='Dense_2')(x)
  x = layer_with_activation(f'{activation}_dense_2', x)
  x = keras.layers.Dense(dense_n, name='Dense_3')(x)
  x = layer_with_activation(f'{activation}_dense_3', x)
  outputs = keras.layers.Dense(NUM_TEMP_CLASSES, name='Output', activation="softmax")(x)

  model = keras.Model(inputs=inputs, outputs=outputs)
  
  model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=8e-4),
        loss='categorical_crossentropy',
        metrics=['accuracy'])
  return model

r_model = get_regressor_model()
cbk = [keras.callbacks.ModelCheckpoint(
           'r.hdf5', save_best_only=True, monitor='val_accuracy', mode='max'
           )]

out = train_test_split(conf, one_hot_temp, test_size=0.1)
train_conf, test_conf, train_one_hot_temp, test_one_hot_temp = out
r_model.fit(train_conf, train_one_hot_temp, 
            epochs=30, validation_split=0.1, callbacks=cbk)
# Out:
# Epoch 1/30
# 254/254 [==============================] - 1s 5ms/step - loss: 1.2644 - accuracy: 0.4343 - val_loss: 0.9454 - val_accuracy: 0.5678
# Epoch 2/30
# 254/254 [==============================] - 1s 4ms/step - loss: 0.9308 - accuracy: 0.5506 - val_loss: 0.9430 - val_accuracy: 0.5311
# Epoch 3/30
# 254/254 [==============================] - 1s 4ms/step - loss: 0.8887 - accuracy: 0.5709 - val_loss: 0.9100 - val_accuracy: 0.5656
# Epoch 4/30
# 254/254 [==============================] - 1s 4ms/step - loss: 0.8614 - accuracy: 0.5831 - val_loss: 0.8230 - val_accuracy: 0.5967
# Epoch 5/30
# 254/254 [==============================] - 1s 4ms/step - loss: 0.8459 - accuracy: 0.5920 - val_loss: 0.8899 - val_accuracy: 0.5633
# Epoch 6/30
# 254/254 [==============================] - 1s 4ms/step - loss: 0.8389 - accuracy: 0.5979 - val_loss: 0.8696 - val_accuracy: 0.6200
# Epoch 7/30
# 254/254 [==============================] - 1s 4ms/step - loss: 0.8285 - accuracy: 0.5999 - val_loss: 0.8157 - val_accuracy: 0.5956
# Epoch 8/30
# 254/254 [==============================] - 1s 4ms/step - loss: 0.8031 - accuracy: 0.6088 - val_loss: 0.7993 - val_accuracy: 0.6122
# Epoch 9/30
# 254/254 [==============================] - 1s 4ms/step - loss: 0.7955 - accuracy: 0.6283 - val_loss: 0.8996 - val_accuracy: 0.5733
# Epoch 10/30
# 254/254 [==============================] - 1s 4ms/step - loss: 0.7932 - accuracy: 0.6217 - val_loss: 0.7985 - val_accuracy: 0.6211
# Epoch 11/30
# 254/254 [==============================] - 1s 4ms/step - loss: 0.7912 - accuracy: 0.6212 - val_loss: 0.7784 - val_accuracy: 0.6278
# Epoch 12/30
# 254/254 [==============================] - 1s 4ms/step - loss: 0.7811 - accuracy: 0.6285 - val_loss: 0.8809 - val_accuracy: 0.5933
# Epoch 13/30
# 254/254 [==============================] - 1s 4ms/step - loss: 0.7812 - accuracy: 0.6328 - val_loss: 0.7806 - val_accuracy: 0.6133
# Epoch 14/30
# 254/254 [==============================] - 1s 4ms/step - loss: 0.7772 - accuracy: 0.6283 - val_loss: 0.8138 - val_accuracy: 0.6144
# Epoch 15/30
# 254/254 [==============================] - 1s 4ms/step - loss: 0.7682 - accuracy: 0.6333 - val_loss: 0.8239 - val_accuracy: 0.6044
# Epoch 16/30
# 254/254 [==============================] - 1s 4ms/step - loss: 0.7694 - accuracy: 0.6388 - val_loss: 0.8358 - val_accuracy: 0.6111
# Epoch 17/30
# 254/254 [==============================] - 1s 4ms/step - loss: 0.7721 - accuracy: 0.6312 - val_loss: 0.8055 - val_accuracy: 0.6056
# Epoch 18/30
# 254/254 [==============================] - 1s 4ms/step - loss: 0.7545 - accuracy: 0.6442 - val_loss: 0.8586 - val_accuracy: 0.5856
# Epoch 19/30
# 254/254 [==============================] - 1s 4ms/step - loss: 0.7530 - accuracy: 0.6373 - val_loss: 0.8303 - val_accuracy: 0.5944
# Epoch 20/30
# 254/254 [==============================] - 1s 4ms/step - loss: 0.7469 - accuracy: 0.6428 - val_loss: 0.7997 - val_accuracy: 0.6267
# Epoch 21/30
# 254/254 [==============================] - 1s 4ms/step - loss: 0.7498 - accuracy: 0.6421 - val_loss: 0.9594 - val_accuracy: 0.5622
# Epoch 22/30
# 254/254 [==============================] - 1s 4ms/step - loss: 0.7601 - accuracy: 0.6405 - val_loss: 0.8471 - val_accuracy: 0.6144
# Epoch 23/30
# 254/254 [==============================] - 1s 4ms/step - loss: 0.7275 - accuracy: 0.6574 - val_loss: 0.7968 - val_accuracy: 0.6244
# Epoch 24/30
# 254/254 [==============================] - 1s 4ms/step - loss: 0.7193 - accuracy: 0.6573 - val_loss: 0.8056 - val_accuracy: 0.6156
# Epoch 25/30
# 254/254 [==============================] - 1s 4ms/step - loss: 0.7434 - accuracy: 0.6453 - val_loss: 0.8221 - val_accuracy: 0.6056
# Epoch 26/30
# 254/254 [==============================] - 1s 4ms/step - loss: 0.7329 - accuracy: 0.6512 - val_loss: 0.9794 - val_accuracy: 0.5600
# Epoch 27/30
# 254/254 [==============================] - 1s 4ms/step - loss: 0.7063 - accuracy: 0.6625 - val_loss: 0.8352 - val_accuracy: 0.6000
# Epoch 28/30
# 254/254 [==============================] - 1s 4ms/step - loss: 0.7088 - accuracy: 0.6572 - val_loss: 0.8280 - val_accuracy: 0.6044
# Epoch 29/30
# 254/254 [==============================] - 1s 4ms/step - loss: 0.7208 - accuracy: 0.6626 - val_loss: 0.8177 - val_accuracy: 0.6000
# Epoch 30/30
# 254/254 [==============================] - 1s 4ms/step - loss: 0.7063 - accuracy: 0.6622 - val_loss: 0.7997 - val_accuracy: 0.6178

# %%
r_model = keras.models.load_model("r.hdf5")
r_model.evaluate(test_conf, test_one_hot_temp)
# Out:
# 32/32 [==============================] - 0s 3ms/step - loss: 0.7834 - accuracy: 0.6330
# [0.7834379076957703, 0.6330000162124634]

# %% [markdown]
# Definisco un modello Keras custom, con un subclassing da `keras.Model`.
# In particolare distinguo tre modalità di allenamento in base all'input dato al discriminatore
# *   A: (immagini reali, temperature reali) -> target 1, (immagini fake, temperature usate per generarle)-> target 0
#
# *   B: (immagini reali, temperature reali) -> target 1, (immagini reali, temperature random)-> target 0, (immagini fake, temperature usate per generarle) -> target 0
#
# *   C: (immagini reali, temperature reali) -> target 1, (immagini reali, temperature random)-> target 0, (immagini fake, temperature ottenute dal regressore sulle immagini fake)-> target 0

# %%
# Modello DCGAN: implementiamo un keras.Model custom
class DCGAN(keras.Model):
    def __init__(self, discriminator, generator, regressor, latent_dim, mode=None):
        super().__init__()
        self.discriminator = discriminator
        self.generator = generator
        self.regressor = regressor
        self.latent_dim = latent_dim
        self.mode = mode

    # funzione per la compilazione
    def compile(self, d_optimizer, g_optimizer, loss_fn):
        super().compile()
        self.d_optimizer = d_optimizer
        self.g_optimizer = g_optimizer
        self.loss_fn = loss_fn

    def train_step(self, train_batch):
        if isinstance(train_batch, tuple): #verifica che l'input isa una python tuple (numpy tensor)
            real_images, real_classes = train_batch

        # 1) campiona un batch di punti random nello spazio latente: z
        batch_size = tf.shape(real_images)[0]
        rand_classes = tf.one_hot(
            tf.random.uniform(
                shape=(batch_size,), 
                maxval=NUM_TEMP_CLASSES, 
                dtype=tf.int32
            ),
            NUM_TEMP_CLASSES,
        )
        rand_latent = tf.random.normal(shape=(batch_size, self.latent_dim))

        # 2) usa il generatore per creare dai vettori latenti immagini fake: immagine = G(z)
        generated_images = self.generator([rand_classes, rand_latent])
        
        # 3) determina la temperatura delle immagini generate grazie alla rete ausiliaria

        if self.mode == "A":
            # 4) combina le immagini fake con quelle reali 
            combined_images = tf.concat([
                            real_images, generated_images,# real_images,
            ], axis=0)

            combined_classes = tf.concat([
                            real_classes, rand_classes,# rand_classes,
            ], axis=0)

            # 5) assegna le label corrette (fae vs reale)
            labels = tf.concat([
                tf.ones((batch_size, 1)),  #immagini reali, temperature reali
                tf.zeros((batch_size, 1)), #immagini generate, temperature corrispondenti
                #tf.zeros((batch_size, 1)), #immagini reali, temperature no
            ], axis=0)

        if self.mode == "B":
            generated_classes = self.regressor(generated_images)

            # 4) combina le immagini fake con quelle reali 
            combined_images = tf.concat([
                             real_images, generated_images, real_images,
            ], axis=0)

            combined_classes = tf.concat([
                             real_classes, rand_classes, rand_classes,
            ], axis=0)

            # 5) assegna le label corrette (fae vs reale)
            labels = tf.concat([
                tf.ones((batch_size, 1)),  #immagini reali, temperature reali
                tf.zeros((batch_size, 1)), #immagini generate, temperature corrispondenti
                tf.zeros((batch_size, 1)), #immagini reali, temperature no
            ], axis=0)

        if self.mode == "C":
            generated_classes = self.regressor(generated_images)
            # 4) combina le immagini fake con quelle reali 
            combined_images = tf.concat([
                             real_images, generated_images, real_images,
            ], axis=0)

            combined_classes = tf.concat([
                              real_classes, generated_classes, rand_classes,
            ], axis=0)

            # 5) assegna le label corrette (fae vs reale)
            labels = tf.concat([
                tf.ones((batch_size, 1)),  #immagini reali, temperature reali
                tf.zeros((batch_size, 1)), #immagini generate, temperature corrispondenti
                tf.zeros((batch_size, 1)), #immagini reali, temperature no
            ], axis=0)

        # 6) Trucco per diminuire la probabilità di collasso della rete (si aggiunge un po' di rumore random alle label) 
        labels += 0.05 * tf.random.uniform(tf.shape(labels))

        # 7) Training del discriminatore D
        with tf.GradientTape() as tape: #autograd
            predictions = self.discriminator(
                [combined_images, combined_classes]) #predizione = D(immagini)
            d_loss = self.loss_fn(labels, predictions) #calcolo loss
        grads = tape.gradient(d_loss, self.discriminator.trainable_weights) #backprop
        self.d_optimizer.apply_gradients(
            zip(grads, self.discriminator.trainable_weights) #aggiornamento pesi
        )

        # 8) crea un vettore di label corrispondenti a tutte immagii reali
        misleading_labels = tf.ones((batch_size, 1))

        # 9) Training del generatore (non si devono aggiornare ovviamente i pesi del discriminatore)
        with tf.GradientTape() as tape:
            generated_images = self.generator([rand_classes, rand_latent])
            predictions = self.discriminator([generated_images, rand_classes]) #predizione = D(G(z))
            g_loss = self.loss_fn(misleading_labels, predictions) #calcolo loss
        grads = tape.gradient(g_loss, self.generator.trainable_weights) #backprop
        self.g_optimizer.apply_gradients(zip(grads, self.generator.trainable_weights)) #aggiornamento pesi

        return {"d_loss": d_loss, "g_loss": g_loss}

# %% [markdown]
# Definisco una callback custom, con un subclassing di `keras.callbacks.Callback`,
# che alla fine di ogni epoca salva come immagine un set di configurazioni generate (una per ciascuna classe di temperatura).

# %%
# custom callback to save generated images peridoically during training
class GANMonitor(keras.callbacks.Callback):
    def __init__(self, num_img=11, latent_dim=128, norma=1.0):
        self.num_img = num_img
        self.latent_dim = latent_dim
        self.norma = norma

    def on_epoch_end(self, epoch, logs=None):
        classes = tf.one_hot(range(self.num_img), NUM_TEMP_CLASSES)
        latent = tf.random.normal(shape=(self.num_img, self.latent_dim))
        generated_images = self.model.generator([classes, latent])
        generated_images = generated_images * self.norma
        fig, axs = plt.subplots(1, self.num_img, figsize=(18, 5))
        for i in range(self.num_img):
            img = generated_images[i].numpy().reshape(28, 28)
            axs[i].imshow(img)
        fig.savefig(f"{epoch}.png")
        plt.close()

# %% [markdown]
# Come ottimizzatore utilizzo ADAM, con $\eta=0.0002,\,\beta=0.5$ (best-practice per le GAN).

# %%
# Training della GAN

# Ottimizzatori di G e D
# learning_rate=0.0002, beta_1=0.5 are recommened
generator_optimizer = keras.optimizers.Adam(
    learning_rate=0.0002, beta_1=0.5, beta_2=0.9)

discriminator_optimizer = keras.optimizers.Adam(
    learning_rate=0.0002, beta_1=0.5, beta_2=0.9)
# Loss function
gan_loss = keras.losses.BinaryCrossentropy(from_logits=True)

# Callbacks
cbk = GANMonitor(num_img=NUM_TEMP_CLASSES, latent_dim=LATENT_DIM, norma=255)

# %% [markdown]
# Eseguo il training della GAN, con le tre modalità A, B e C in sequenza (300 epoche ciascuna).

# %%
for mode in ["A", "B", "C"]:
  # Istanziamento modello
  gan = DCGAN(discriminator=d_model, generator=g_model, regressor=r_model, 
              latent_dim=LATENT_DIM, mode=mode)

  # Compilazione
  gan.compile(d_optimizer=discriminator_optimizer,
      g_optimizer=generator_optimizer,
      loss_fn=gan_loss,
  )

  gan.fit(dataset, epochs=400, batch_size=64, callbacks=[cbk])
# Out:
# Epoch 1/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.6510 - g_loss: 0.5485
# Epoch 2/1000
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.5682 - g_loss: 0.6534
# Epoch 3/1000
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.5667 - g_loss: 0.6822
# Epoch 4/1000
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.5579 - g_loss: 0.6845
# Epoch 5/1000
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.5479 - g_loss: 0.6885
# Epoch 6/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5137 - g_loss: 0.6824
# Epoch 7/1000
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.5791 - g_loss: 0.6725
# Epoch 8/1000
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.5528 - g_loss: 0.6863
# Epoch 9/1000
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.5485 - g_loss: 0.6912
# Epoch 10/1000
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.5424 - g_loss: 0.6891
# Epoch 11/1000
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.5712 - g_loss: 0.6630
# Epoch 12/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5632 - g_loss: 0.6814
# Epoch 13/1000
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.5676 - g_loss: 0.6796
# Epoch 14/1000
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.5682 - g_loss: 0.6831
# Epoch 15/1000
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.5673 - g_loss: 0.6843
# Epoch 16/1000
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.5704 - g_loss: 0.6798
# Epoch 17/1000
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.5681 - g_loss: 0.6772
# Epoch 18/1000
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.5647 - g_loss: 0.6691
# Epoch 19/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.5743 - g_loss: 0.6774
# Epoch 20/1000
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.5777 - g_loss: 0.6757
# Epoch 21/1000
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.5755 - g_loss: 0.6744
# Epoch 22/1000
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.5745 - g_loss: 0.6758
# Epoch 23/1000
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.5734 - g_loss: 0.6762
# Epoch 24/1000
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.5733 - g_loss: 0.6795
# Epoch 25/1000
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.5737 - g_loss: 0.6763
# Epoch 26/1000
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.5712 - g_loss: 0.6728
# Epoch 27/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.5710 - g_loss: 0.6695
# Epoch 28/1000
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.5679 - g_loss: 0.6677
# Epoch 29/1000
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.5664 - g_loss: 0.6725
# Epoch 30/1000
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.5657 - g_loss: 0.6708
# Epoch 31/1000
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.5741 - g_loss: 0.6632
# Epoch 32/1000
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.5758 - g_loss: 0.6615
# Epoch 33/1000
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.5764 - g_loss: 0.6642
# Epoch 34/1000
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.5746 - g_loss: 0.6709
# Epoch 35/1000
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.5696 - g_loss: 0.6662
# Epoch 36/1000
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.5699 - g_loss: 0.6608
# Epoch 37/1000
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.5667 - g_loss: 0.6607
# Epoch 38/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.5685 - g_loss: 0.6624
# Epoch 39/1000
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.5741 - g_loss: 0.6594
# Epoch 40/1000
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.5809 - g_loss: 0.6432
# Epoch 41/1000
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.5804 - g_loss: 0.6444
# Epoch 42/1000
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.5797 - g_loss: 0.6410
# Epoch 43/1000
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.5737 - g_loss: 0.6471
# Epoch 44/1000
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.5711 - g_loss: 0.6526
# Epoch 45/1000
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.5693 - g_loss: 0.6490
# Epoch 46/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5733 - g_loss: 0.6481
# Epoch 47/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5767 - g_loss: 0.6487
# Epoch 48/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5863 - g_loss: 0.6406
# Epoch 49/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5837 - g_loss: 0.6393
# Epoch 50/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5868 - g_loss: 0.6291
# Epoch 51/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5872 - g_loss: 0.6334
# Epoch 52/1000
# 157/157 [==============================] - 3s 21ms/step - d_loss: 0.5719 - g_loss: 0.6444
# Epoch 53/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5688 - g_loss: 0.6541
# Epoch 54/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5746 - g_loss: 0.6455
# Epoch 55/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5773 - g_loss: 0.6367
# Epoch 56/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5802 - g_loss: 0.6282
# Epoch 57/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5697 - g_loss: 0.6417
# Epoch 58/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5720 - g_loss: 0.6452
# Epoch 59/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5760 - g_loss: 0.6401
# Epoch 60/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5713 - g_loss: 0.6393
# Epoch 61/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5709 - g_loss: 0.6424
# Epoch 62/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5723 - g_loss: 0.6412
# Epoch 63/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5745 - g_loss: 0.6348
# Epoch 64/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5702 - g_loss: 0.6313
# Epoch 65/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5655 - g_loss: 0.6470
# Epoch 66/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5629 - g_loss: 0.6498
# Epoch 67/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5653 - g_loss: 0.6449
# Epoch 68/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5674 - g_loss: 0.6478
# Epoch 69/1000
# 157/157 [==============================] - 3s 22ms/step - d_loss: 0.5624 - g_loss: 0.6475
# Epoch 70/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5652 - g_loss: 0.6451
# Epoch 71/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5637 - g_loss: 0.6480
# Epoch 72/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5681 - g_loss: 0.6454
# Epoch 73/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5670 - g_loss: 0.6377
# Epoch 74/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5652 - g_loss: 0.6416
# Epoch 75/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5612 - g_loss: 0.6539
# Epoch 76/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5598 - g_loss: 0.6507
# Epoch 77/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5627 - g_loss: 0.6504
# Epoch 78/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5658 - g_loss: 0.6427
# Epoch 79/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5629 - g_loss: 0.6483
# Epoch 80/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5620 - g_loss: 0.6519
# Epoch 81/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5625 - g_loss: 0.6521
# Epoch 82/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5613 - g_loss: 0.6555
# Epoch 83/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5585 - g_loss: 0.6518
# Epoch 84/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5584 - g_loss: 0.6561
# Epoch 85/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5629 - g_loss: 0.6527
# Epoch 86/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5618 - g_loss: 0.6581
# Epoch 87/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5613 - g_loss: 0.6527
# Epoch 88/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5634 - g_loss: 0.6521
# Epoch 89/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5622 - g_loss: 0.6535
# Epoch 90/1000
# 157/157 [==============================] - 4s 24ms/step - d_loss: 0.5646 - g_loss: 0.6452
# Epoch 91/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5607 - g_loss: 0.6518
# Epoch 92/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5617 - g_loss: 0.6527
# Epoch 93/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5600 - g_loss: 0.6542
# Epoch 94/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5625 - g_loss: 0.6535
# Epoch 95/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5596 - g_loss: 0.6541
# Epoch 96/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5585 - g_loss: 0.6600
# Epoch 97/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5617 - g_loss: 0.6542
# Epoch 98/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5630 - g_loss: 0.6533
# Epoch 99/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5640 - g_loss: 0.6546
# Epoch 100/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5615 - g_loss: 0.6537
# Epoch 101/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5600 - g_loss: 0.6557
# Epoch 102/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5607 - g_loss: 0.6571
# Epoch 103/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5602 - g_loss: 0.6620
# Epoch 104/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5617 - g_loss: 0.6603
# Epoch 105/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5620 - g_loss: 0.6568
# Epoch 106/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5642 - g_loss: 0.6500
# Epoch 107/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5638 - g_loss: 0.6581
# Epoch 108/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5651 - g_loss: 0.6547
# Epoch 109/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5713 - g_loss: 0.6596
# Epoch 110/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5703 - g_loss: 0.6566
# Epoch 111/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5685 - g_loss: 0.6601
# Epoch 112/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5654 - g_loss: 0.6573
# Epoch 113/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5653 - g_loss: 0.6662
# Epoch 114/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5662 - g_loss: 0.6626
# Epoch 115/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5679 - g_loss: 0.6598
# Epoch 116/1000
# 157/157 [==============================] - 4s 25ms/step - d_loss: 0.5692 - g_loss: 0.6585
# Epoch 117/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5736 - g_loss: 0.6594
# Epoch 118/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5778 - g_loss: 0.6530
# Epoch 119/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5780 - g_loss: 0.6480
# Epoch 120/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5759 - g_loss: 0.6534
# Epoch 121/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5739 - g_loss: 0.6525
# Epoch 122/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5752 - g_loss: 0.6487
# Epoch 123/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5716 - g_loss: 0.6542
# Epoch 124/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5746 - g_loss: 0.6521
# Epoch 125/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5857 - g_loss: 0.6407
# Epoch 126/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5834 - g_loss: 0.6424
# Epoch 127/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5769 - g_loss: 0.6484
# Epoch 128/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5694 - g_loss: 0.6558
# Epoch 129/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5736 - g_loss: 0.6500
# Epoch 130/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5738 - g_loss: 0.6520
# Epoch 131/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5778 - g_loss: 0.6546
# Epoch 132/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5785 - g_loss: 0.6487
# Epoch 133/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5900 - g_loss: 0.6415
# Epoch 134/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5833 - g_loss: 0.6550
# Epoch 135/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5843 - g_loss: 0.6541
# Epoch 136/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5792 - g_loss: 0.6461
# Epoch 137/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5810 - g_loss: 0.6488
# Epoch 138/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5846 - g_loss: 0.6497
# Epoch 139/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5757 - g_loss: 0.6531
# Epoch 140/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5734 - g_loss: 0.6544
# Epoch 141/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5770 - g_loss: 0.6549
# Epoch 142/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5722 - g_loss: 0.6525
# Epoch 143/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5808 - g_loss: 0.6506
# Epoch 144/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5788 - g_loss: 0.6490
# Epoch 145/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5881 - g_loss: 0.6446
# Epoch 146/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5823 - g_loss: 0.6492
# Epoch 147/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5774 - g_loss: 0.6542
# Epoch 148/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5788 - g_loss: 0.6533
# Epoch 149/1000
# 157/157 [==============================] - 4s 27ms/step - d_loss: 0.5814 - g_loss: 0.6451
# Epoch 150/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5798 - g_loss: 0.6515
# Epoch 151/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5743 - g_loss: 0.6476
# Epoch 152/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5754 - g_loss: 0.6536
# Epoch 153/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5728 - g_loss: 0.6516
# Epoch 154/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5757 - g_loss: 0.6510
# Epoch 155/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5759 - g_loss: 0.6483
# Epoch 156/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5745 - g_loss: 0.6499
# Epoch 157/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5751 - g_loss: 0.6564
# Epoch 158/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5715 - g_loss: 0.6582
# Epoch 159/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5663 - g_loss: 0.6594
# Epoch 160/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5703 - g_loss: 0.6604
# Epoch 161/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5747 - g_loss: 0.6535
# Epoch 162/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5753 - g_loss: 0.6519
# Epoch 163/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5735 - g_loss: 0.6557
# Epoch 164/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5697 - g_loss: 0.6586
# Epoch 165/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5674 - g_loss: 0.6614
# Epoch 166/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5646 - g_loss: 0.6570
# Epoch 167/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5677 - g_loss: 0.6586
# Epoch 168/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5710 - g_loss: 0.6554
# Epoch 169/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5746 - g_loss: 0.6511
# Epoch 170/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5700 - g_loss: 0.6535
# Epoch 171/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5716 - g_loss: 0.6546
# Epoch 172/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5749 - g_loss: 0.6569
# Epoch 173/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5781 - g_loss: 0.6456
# Epoch 174/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5693 - g_loss: 0.6549
# Epoch 175/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5675 - g_loss: 0.6619
# Epoch 176/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5669 - g_loss: 0.6577
# Epoch 177/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5649 - g_loss: 0.6647
# Epoch 178/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5643 - g_loss: 0.6596
# Epoch 179/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5637 - g_loss: 0.6601
# Epoch 180/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5690 - g_loss: 0.6565
# Epoch 181/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5740 - g_loss: 0.6594
# Epoch 182/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5751 - g_loss: 0.6532
# Epoch 183/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5672 - g_loss: 0.6565
# Epoch 184/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5719 - g_loss: 0.6506
# Epoch 185/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5705 - g_loss: 0.6560
# Epoch 186/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5697 - g_loss: 0.6625
# Epoch 187/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5786 - g_loss: 0.6588
# Epoch 188/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5751 - g_loss: 0.6520
# Epoch 189/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5721 - g_loss: 0.6567
# Epoch 190/1000
# 157/157 [==============================] - 5s 29ms/step - d_loss: 0.5684 - g_loss: 0.6619
# Epoch 191/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5698 - g_loss: 0.6633
# Epoch 192/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5746 - g_loss: 0.6589
# Epoch 193/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5755 - g_loss: 0.6564
# Epoch 194/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5765 - g_loss: 0.6562
# Epoch 195/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5765 - g_loss: 0.6627
# Epoch 196/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5672 - g_loss: 0.6596
# Epoch 197/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5686 - g_loss: 0.6529
# Epoch 198/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5654 - g_loss: 0.6573
# Epoch 199/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5677 - g_loss: 0.6592
# Epoch 200/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5668 - g_loss: 0.6616
# Epoch 201/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5685 - g_loss: 0.6621
# Epoch 202/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5726 - g_loss: 0.6576
# Epoch 203/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5678 - g_loss: 0.6625
# Epoch 204/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5639 - g_loss: 0.6638
# Epoch 205/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5626 - g_loss: 0.6630
# Epoch 206/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5643 - g_loss: 0.6608
# Epoch 207/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5692 - g_loss: 0.6609
# Epoch 208/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5659 - g_loss: 0.6593
# Epoch 209/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5671 - g_loss: 0.6623
# Epoch 210/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5640 - g_loss: 0.6628
# Epoch 211/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5675 - g_loss: 0.6591
# Epoch 212/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5728 - g_loss: 0.6564
# Epoch 213/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5728 - g_loss: 0.6583
# Epoch 214/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5720 - g_loss: 0.6526
# Epoch 215/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5691 - g_loss: 0.6551
# Epoch 216/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5702 - g_loss: 0.6593
# Epoch 217/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5669 - g_loss: 0.6610
# Epoch 218/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5677 - g_loss: 0.6650
# Epoch 219/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5640 - g_loss: 0.6599
# Epoch 220/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5648 - g_loss: 0.6557
# Epoch 221/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5637 - g_loss: 0.6607
# Epoch 222/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5678 - g_loss: 0.6585
# Epoch 223/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5642 - g_loss: 0.6601
# Epoch 224/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5606 - g_loss: 0.6654
# Epoch 225/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5643 - g_loss: 0.6612
# Epoch 226/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5632 - g_loss: 0.6633
# Epoch 227/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5620 - g_loss: 0.6654
# Epoch 228/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5633 - g_loss: 0.6595
# Epoch 229/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5694 - g_loss: 0.6599
# Epoch 230/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5671 - g_loss: 0.6649
# Epoch 231/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5670 - g_loss: 0.6577
# Epoch 232/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5644 - g_loss: 0.6657
# Epoch 233/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5632 - g_loss: 0.6635
# Epoch 234/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5651 - g_loss: 0.6571
# Epoch 235/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5590 - g_loss: 0.6640
# Epoch 236/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5594 - g_loss: 0.6652
# Epoch 237/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5645 - g_loss: 0.6635
# Epoch 238/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5634 - g_loss: 0.6588
# Epoch 239/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5634 - g_loss: 0.6600
# Epoch 240/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5699 - g_loss: 0.6597
# Epoch 241/1000
# 157/157 [==============================] - 5s 32ms/step - d_loss: 0.5665 - g_loss: 0.6644
# Epoch 242/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5667 - g_loss: 0.6665
# Epoch 243/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5640 - g_loss: 0.6616
# Epoch 244/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5653 - g_loss: 0.6624
# Epoch 245/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5700 - g_loss: 0.6614
# Epoch 246/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5743 - g_loss: 0.6552
# Epoch 247/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5745 - g_loss: 0.6597
# Epoch 248/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5649 - g_loss: 0.6616
# Epoch 249/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5637 - g_loss: 0.6625
# Epoch 250/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5626 - g_loss: 0.6620
# Epoch 251/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5659 - g_loss: 0.6612
# Epoch 252/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5638 - g_loss: 0.6588
# Epoch 253/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5659 - g_loss: 0.6610
# Epoch 254/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5642 - g_loss: 0.6664
# Epoch 255/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5631 - g_loss: 0.6622
# Epoch 256/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5682 - g_loss: 0.6623
# Epoch 257/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5637 - g_loss: 0.6598
# Epoch 258/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5643 - g_loss: 0.6610
# Epoch 259/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5646 - g_loss: 0.6629
# Epoch 260/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5626 - g_loss: 0.6619
# Epoch 261/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5651 - g_loss: 0.6636
# Epoch 262/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5631 - g_loss: 0.6663
# Epoch 263/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5579 - g_loss: 0.6625
# Epoch 264/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5622 - g_loss: 0.6665
# Epoch 265/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5668 - g_loss: 0.6587
# Epoch 266/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5635 - g_loss: 0.6639
# Epoch 267/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5613 - g_loss: 0.6575
# Epoch 268/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5653 - g_loss: 0.6615
# Epoch 269/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5653 - g_loss: 0.6592
# Epoch 270/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5628 - g_loss: 0.6627
# Epoch 271/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5606 - g_loss: 0.6611
# Epoch 272/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5603 - g_loss: 0.6648
# Epoch 273/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5626 - g_loss: 0.6629
# Epoch 274/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5618 - g_loss: 0.6642
# Epoch 275/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5628 - g_loss: 0.6616
# Epoch 276/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5605 - g_loss: 0.6627
# Epoch 277/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5630 - g_loss: 0.6613
# Epoch 278/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5591 - g_loss: 0.6634
# Epoch 279/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5615 - g_loss: 0.6607
# Epoch 280/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5626 - g_loss: 0.6630
# Epoch 281/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5621 - g_loss: 0.6651
# Epoch 282/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5603 - g_loss: 0.6597
# Epoch 283/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5578 - g_loss: 0.6650
# Epoch 284/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5566 - g_loss: 0.6640
# Epoch 285/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5633 - g_loss: 0.6629
# Epoch 286/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5562 - g_loss: 0.6612
# Epoch 287/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5628 - g_loss: 0.6687
# Epoch 288/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5607 - g_loss: 0.6625
# Epoch 289/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5605 - g_loss: 0.6645
# Epoch 290/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5588 - g_loss: 0.6661
# Epoch 291/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5610 - g_loss: 0.6673
# Epoch 292/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5628 - g_loss: 0.6607
# Epoch 293/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5585 - g_loss: 0.6602
# Epoch 294/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5617 - g_loss: 0.6678
# Epoch 295/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5619 - g_loss: 0.6612
# Epoch 296/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5584 - g_loss: 0.6666
# Epoch 297/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5565 - g_loss: 0.6676
# Epoch 298/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5554 - g_loss: 0.6663
# Epoch 299/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5548 - g_loss: 0.6665
# Epoch 300/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5543 - g_loss: 0.6646
# Epoch 301/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5563 - g_loss: 0.6692
# Epoch 302/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5571 - g_loss: 0.6639
# Epoch 303/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5582 - g_loss: 0.6619
# Epoch 304/1000
# 157/157 [==============================] - 6s 36ms/step - d_loss: 0.5589 - g_loss: 0.6642
# Epoch 305/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5613 - g_loss: 0.6688
# Epoch 306/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5604 - g_loss: 0.6658
# Epoch 307/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5561 - g_loss: 0.6703
# Epoch 308/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5574 - g_loss: 0.6675
# Epoch 309/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5604 - g_loss: 0.6646
# Epoch 310/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5641 - g_loss: 0.6673
# Epoch 311/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5612 - g_loss: 0.6664
# Epoch 312/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5575 - g_loss: 0.6670
# Epoch 313/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5598 - g_loss: 0.6639
# Epoch 314/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5594 - g_loss: 0.6651
# Epoch 315/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5587 - g_loss: 0.6640
# Epoch 316/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5593 - g_loss: 0.6655
# Epoch 317/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5585 - g_loss: 0.6616
# Epoch 318/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5593 - g_loss: 0.6644
# Epoch 319/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5612 - g_loss: 0.6644
# Epoch 320/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5563 - g_loss: 0.6638
# Epoch 321/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5547 - g_loss: 0.6654
# Epoch 322/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5534 - g_loss: 0.6642
# Epoch 323/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5554 - g_loss: 0.6640
# Epoch 324/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5568 - g_loss: 0.6657
# Epoch 325/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5593 - g_loss: 0.6645
# Epoch 326/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5554 - g_loss: 0.6605
# Epoch 327/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5525 - g_loss: 0.6674
# Epoch 328/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5555 - g_loss: 0.6637
# Epoch 329/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5566 - g_loss: 0.6668
# Epoch 330/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5552 - g_loss: 0.6668
# Epoch 331/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5569 - g_loss: 0.6669
# Epoch 332/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5585 - g_loss: 0.6636
# Epoch 333/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5544 - g_loss: 0.6642
# Epoch 334/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5530 - g_loss: 0.6668
# Epoch 335/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5569 - g_loss: 0.6662
# Epoch 336/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5552 - g_loss: 0.6634
# Epoch 337/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5545 - g_loss: 0.6689
# Epoch 338/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5549 - g_loss: 0.6684
# Epoch 339/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5567 - g_loss: 0.6650
# Epoch 340/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5540 - g_loss: 0.6655
# Epoch 341/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5527 - g_loss: 0.6670
# Epoch 342/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5531 - g_loss: 0.6692
# Epoch 343/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5601 - g_loss: 0.6664
# Epoch 344/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5584 - g_loss: 0.6644
# Epoch 345/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5609 - g_loss: 0.6640
# Epoch 346/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5601 - g_loss: 0.6637
# Epoch 347/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5575 - g_loss: 0.6677
# Epoch 348/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5619 - g_loss: 0.6672
# Epoch 349/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5621 - g_loss: 0.6638
# Epoch 350/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5584 - g_loss: 0.6635
# Epoch 351/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5582 - g_loss: 0.6606
# Epoch 352/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5593 - g_loss: 0.6610
# Epoch 353/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5600 - g_loss: 0.6655
# Epoch 354/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5585 - g_loss: 0.6584
# Epoch 355/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5571 - g_loss: 0.6648
# Epoch 356/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5601 - g_loss: 0.6648
# Epoch 357/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5539 - g_loss: 0.6668
# Epoch 358/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5583 - g_loss: 0.6696
# Epoch 359/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5565 - g_loss: 0.6693
# Epoch 360/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5588 - g_loss: 0.6634
# Epoch 361/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5573 - g_loss: 0.6684
# Epoch 362/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5558 - g_loss: 0.6667
# Epoch 363/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5578 - g_loss: 0.6625
# Epoch 364/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5575 - g_loss: 0.6619
# Epoch 365/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5576 - g_loss: 0.6644
# Epoch 366/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5576 - g_loss: 0.6666
# Epoch 367/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5556 - g_loss: 0.6652
# Epoch 368/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5557 - g_loss: 0.6678
# Epoch 369/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5555 - g_loss: 0.6661
# Epoch 370/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5542 - g_loss: 0.6668
# Epoch 371/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5560 - g_loss: 0.6672
# Epoch 372/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5568 - g_loss: 0.6679
# Epoch 373/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5557 - g_loss: 0.6684
# Epoch 374/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5570 - g_loss: 0.6638
# Epoch 375/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5562 - g_loss: 0.6661
# Epoch 376/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5602 - g_loss: 0.6701
# Epoch 377/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5538 - g_loss: 0.6665
# Epoch 378/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5552 - g_loss: 0.6637
# Epoch 379/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5534 - g_loss: 0.6667
# Epoch 380/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5557 - g_loss: 0.6652
# Epoch 381/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5557 - g_loss: 0.6707
# Epoch 382/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5532 - g_loss: 0.6667
# Epoch 383/1000
# 157/157 [==============================] - 7s 42ms/step - d_loss: 0.5563 - g_loss: 0.6635
# Epoch 384/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5511 - g_loss: 0.6681
# Epoch 385/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5539 - g_loss: 0.6659
# Epoch 386/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5528 - g_loss: 0.6673
# Epoch 387/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5524 - g_loss: 0.6700
# Epoch 388/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5505 - g_loss: 0.6705
# Epoch 389/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5530 - g_loss: 0.6676
# Epoch 390/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5534 - g_loss: 0.6659
# Epoch 391/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5544 - g_loss: 0.6683
# Epoch 392/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5522 - g_loss: 0.6700
# Epoch 393/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5519 - g_loss: 0.6684
# Epoch 394/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5514 - g_loss: 0.6667
# Epoch 395/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5519 - g_loss: 0.6700
# Epoch 396/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5495 - g_loss: 0.6650
# Epoch 397/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5510 - g_loss: 0.6669
# Epoch 398/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5523 - g_loss: 0.6691
# Epoch 399/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5521 - g_loss: 0.6670
# Epoch 400/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5514 - g_loss: 0.6686
# Epoch 401/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5521 - g_loss: 0.6680
# Epoch 402/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5516 - g_loss: 0.6658
# Epoch 403/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5565 - g_loss: 0.6671
# Epoch 404/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5544 - g_loss: 0.6654
# Epoch 405/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5542 - g_loss: 0.6625
# Epoch 406/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5556 - g_loss: 0.6631
# Epoch 407/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5523 - g_loss: 0.6640
# Epoch 408/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5543 - g_loss: 0.6590
# Epoch 409/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5568 - g_loss: 0.6630
# Epoch 410/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5523 - g_loss: 0.6662
# Epoch 411/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5517 - g_loss: 0.6686
# Epoch 412/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5503 - g_loss: 0.6674
# Epoch 413/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.5523 - g_loss: 0.6681
# Epoch 414/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5548 - g_loss: 0.6632
# Epoch 415/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5544 - g_loss: 0.6660
# Epoch 416/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5524 - g_loss: 0.6661
# Epoch 417/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5531 - g_loss: 0.6664
# Epoch 418/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5496 - g_loss: 0.6676
# Epoch 419/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5488 - g_loss: 0.6690
# Epoch 420/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5537 - g_loss: 0.6711
# Epoch 421/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5536 - g_loss: 0.6657
# Epoch 422/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5496 - g_loss: 0.6709
# Epoch 423/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5472 - g_loss: 0.6727
# Epoch 424/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5496 - g_loss: 0.6708
# Epoch 425/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5492 - g_loss: 0.6732
# Epoch 426/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5496 - g_loss: 0.6658
# Epoch 427/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5505 - g_loss: 0.6648
# Epoch 428/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5490 - g_loss: 0.6643
# Epoch 429/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5504 - g_loss: 0.6654
# Epoch 430/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5502 - g_loss: 0.6688
# Epoch 431/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5525 - g_loss: 0.6659
# Epoch 432/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5544 - g_loss: 0.6670
# Epoch 433/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5512 - g_loss: 0.6655
# Epoch 434/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5496 - g_loss: 0.6695
# Epoch 435/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5508 - g_loss: 0.6720
# Epoch 436/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5533 - g_loss: 0.6695
# Epoch 437/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5544 - g_loss: 0.6681
# Epoch 438/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5504 - g_loss: 0.6690
# Epoch 439/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5506 - g_loss: 0.6718
# Epoch 440/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5515 - g_loss: 0.6657
# Epoch 441/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5563 - g_loss: 0.6637
# Epoch 442/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5552 - g_loss: 0.6667
# Epoch 443/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5535 - g_loss: 0.6669
# Epoch 444/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5544 - g_loss: 0.6690
# Epoch 445/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5548 - g_loss: 0.6664
# Epoch 446/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5539 - g_loss: 0.6682
# Epoch 447/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5532 - g_loss: 0.6694
# Epoch 448/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5523 - g_loss: 0.6672
# Epoch 449/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5515 - g_loss: 0.6693
# Epoch 450/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5531 - g_loss: 0.6702
# Epoch 451/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5548 - g_loss: 0.6660
# Epoch 452/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5543 - g_loss: 0.6670
# Epoch 453/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5502 - g_loss: 0.6654
# Epoch 454/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5497 - g_loss: 0.6706
# Epoch 455/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5518 - g_loss: 0.6690
# Epoch 456/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5522 - g_loss: 0.6678
# Epoch 457/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5527 - g_loss: 0.6690
# Epoch 458/1000
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5480 - g_loss: 0.6735
# Epoch 459/1000
# ...
# Epoch 432/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6259 - g_loss: 0.6873
# Epoch 433/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6258 - g_loss: 0.6855
# Epoch 434/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6257 - g_loss: 0.6876
# Epoch 435/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6255 - g_loss: 0.6884
# Epoch 436/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6250 - g_loss: 0.6881
# Epoch 437/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6259 - g_loss: 0.6865
# Epoch 438/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6261 - g_loss: 0.6869
# Epoch 439/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6263 - g_loss: 0.6870
# Epoch 440/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6264 - g_loss: 0.6877
# Epoch 441/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6267 - g_loss: 0.6878
# Epoch 442/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6250 - g_loss: 0.6889
# Epoch 443/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6249 - g_loss: 0.6877
# Epoch 444/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6258 - g_loss: 0.6871
# Epoch 445/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6238 - g_loss: 0.6897
# Epoch 446/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6251 - g_loss: 0.6899
# Epoch 447/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6241 - g_loss: 0.6902
# Epoch 448/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6235 - g_loss: 0.6901
# Epoch 449/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6243 - g_loss: 0.6894
# Epoch 450/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6249 - g_loss: 0.6900
# Epoch 451/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6247 - g_loss: 0.6878
# Epoch 452/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6257 - g_loss: 0.6893
# Epoch 453/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6236 - g_loss: 0.6911
# Epoch 454/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6249 - g_loss: 0.6873
# Epoch 455/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6242 - g_loss: 0.6898
# Epoch 456/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6237 - g_loss: 0.6892
# Epoch 457/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6252 - g_loss: 0.6872
# Epoch 458/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6229 - g_loss: 0.6899
# Epoch 459/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6253 - g_loss: 0.6887
# Epoch 460/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6250 - g_loss: 0.6887
# Epoch 461/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6246 - g_loss: 0.6866
# Epoch 462/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6232 - g_loss: 0.6859
# Epoch 463/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6247 - g_loss: 0.6890
# Epoch 464/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6235 - g_loss: 0.6884
# Epoch 465/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6247 - g_loss: 0.6877
# Epoch 466/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6240 - g_loss: 0.6860
# Epoch 467/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6258 - g_loss: 0.6860
# Epoch 468/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6246 - g_loss: 0.6894
# Epoch 469/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6235 - g_loss: 0.6837
# Epoch 470/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6239 - g_loss: 0.6835
# Epoch 471/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6242 - g_loss: 0.6862
# Epoch 472/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6255 - g_loss: 0.6866
# Epoch 473/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6233 - g_loss: 0.6860
# Epoch 474/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6250 - g_loss: 0.6860
# Epoch 475/1000
# 157/157 [==============================] - 18s 118ms/step - d_loss: 0.6249 - g_loss: 0.6862
# Epoch 476/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6249 - g_loss: 0.6883
# Epoch 477/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6252 - g_loss: 0.6882
# Epoch 478/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6250 - g_loss: 0.6862
# Epoch 479/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6263 - g_loss: 0.6851
# Epoch 480/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6259 - g_loss: 0.6871
# Epoch 481/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6265 - g_loss: 0.6863
# Epoch 482/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6257 - g_loss: 0.6882
# Epoch 483/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6244 - g_loss: 0.6889
# Epoch 484/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6251 - g_loss: 0.6869
# Epoch 485/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6261 - g_loss: 0.6882
# Epoch 486/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6263 - g_loss: 0.6879
# Epoch 487/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6264 - g_loss: 0.6878
# Epoch 488/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6257 - g_loss: 0.6871
# Epoch 489/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6260 - g_loss: 0.6880
# Epoch 490/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6254 - g_loss: 0.6856
# Epoch 491/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6250 - g_loss: 0.6876
# Epoch 492/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6255 - g_loss: 0.6871
# Epoch 493/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6258 - g_loss: 0.6863
# Epoch 494/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6236 - g_loss: 0.6891
# Epoch 495/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6257 - g_loss: 0.6890
# Epoch 496/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6245 - g_loss: 0.6890
# Epoch 497/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6243 - g_loss: 0.6879
# Epoch 498/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6241 - g_loss: 0.6894
# Epoch 499/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6256 - g_loss: 0.6890
# Epoch 500/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6244 - g_loss: 0.6867
# Epoch 501/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6267 - g_loss: 0.6847
# Epoch 502/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6257 - g_loss: 0.6830
# Epoch 503/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6269 - g_loss: 0.6849
# Epoch 504/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6259 - g_loss: 0.6867
# Epoch 505/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6256 - g_loss: 0.6889
# Epoch 506/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6248 - g_loss: 0.6887
# Epoch 507/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6249 - g_loss: 0.6894
# Epoch 508/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6276 - g_loss: 0.6882
# Epoch 509/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6268 - g_loss: 0.6848
# Epoch 510/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6266 - g_loss: 0.6845
# Epoch 511/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6282 - g_loss: 0.6863
# Epoch 512/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6260 - g_loss: 0.6862
# Epoch 513/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6244 - g_loss: 0.6842
# Epoch 514/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6240 - g_loss: 0.6869
# Epoch 515/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6261 - g_loss: 0.6853
# Epoch 516/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6258 - g_loss: 0.6863
# Epoch 517/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6257 - g_loss: 0.6863
# Epoch 518/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6256 - g_loss: 0.6847
# Epoch 519/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6246 - g_loss: 0.6853
# Epoch 520/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6239 - g_loss: 0.6855
# Epoch 521/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6250 - g_loss: 0.6884
# Epoch 522/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6256 - g_loss: 0.6860
# Epoch 523/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6247 - g_loss: 0.6876
# Epoch 524/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6251 - g_loss: 0.6877
# Epoch 525/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6244 - g_loss: 0.6878
# Epoch 526/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6253 - g_loss: 0.6899
# Epoch 527/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6249 - g_loss: 0.6873
# Epoch 528/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6227 - g_loss: 0.6899
# Epoch 529/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6253 - g_loss: 0.6894
# Epoch 530/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6246 - g_loss: 0.6870
# Epoch 531/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6236 - g_loss: 0.6889
# Epoch 532/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6224 - g_loss: 0.6875
# Epoch 533/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6247 - g_loss: 0.6873
# Epoch 534/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6248 - g_loss: 0.6891
# Epoch 535/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6242 - g_loss: 0.6896
# Epoch 536/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6244 - g_loss: 0.6894
# Epoch 537/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6244 - g_loss: 0.6883
# Epoch 538/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6246 - g_loss: 0.6881
# Epoch 539/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6249 - g_loss: 0.6855
# Epoch 540/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6245 - g_loss: 0.6887
# Epoch 541/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6251 - g_loss: 0.6868
# Epoch 542/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6248 - g_loss: 0.6872
# Epoch 543/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6236 - g_loss: 0.6892
# Epoch 544/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6245 - g_loss: 0.6888
# Epoch 545/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6258 - g_loss: 0.6821
# Epoch 546/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6262 - g_loss: 0.6853
# Epoch 547/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6242 - g_loss: 0.6883
# Epoch 548/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6256 - g_loss: 0.6846
# Epoch 549/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6267 - g_loss: 0.6861
# Epoch 550/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6241 - g_loss: 0.6815
# Epoch 551/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6268 - g_loss: 0.6870
# Epoch 552/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6277 - g_loss: 0.6830
# Epoch 553/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6255 - g_loss: 0.6890
# Epoch 554/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6252 - g_loss: 0.6880
# Epoch 555/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6251 - g_loss: 0.6887
# Epoch 556/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6246 - g_loss: 0.6887
# Epoch 557/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6250 - g_loss: 0.6891
# Epoch 558/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6256 - g_loss: 0.6868
# Epoch 559/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6234 - g_loss: 0.6902
# Epoch 560/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6263 - g_loss: 0.6891
# Epoch 561/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6252 - g_loss: 0.6894
# Epoch 562/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6264 - g_loss: 0.6885
# Epoch 563/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6242 - g_loss: 0.6880
# Epoch 564/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6250 - g_loss: 0.6892
# Epoch 565/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6252 - g_loss: 0.6885
# Epoch 566/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6269 - g_loss: 0.6844
# Epoch 567/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6254 - g_loss: 0.6857
# Epoch 568/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6255 - g_loss: 0.6896
# Epoch 569/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6242 - g_loss: 0.6900
# Epoch 570/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6250 - g_loss: 0.6860
# Epoch 571/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6252 - g_loss: 0.6876
# Epoch 572/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6243 - g_loss: 0.6868
# Epoch 573/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6232 - g_loss: 0.6893
# Epoch 574/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6250 - g_loss: 0.6898
# Epoch 575/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6249 - g_loss: 0.6867
# Epoch 576/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6260 - g_loss: 0.6878
# Epoch 577/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6235 - g_loss: 0.6889
# Epoch 578/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6249 - g_loss: 0.6870
# Epoch 579/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6264 - g_loss: 0.6846
# Epoch 580/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6259 - g_loss: 0.6888
# Epoch 581/1000
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6246 - g_loss: 0.6892
# Epoch 582/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6266 - g_loss: 0.6863
# Epoch 583/1000
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6248 - g_loss: 0.6884

# %% [markdown]
# Per garantire maggiore variabilità al generatore, aggiungo un layer finale che inverte tutti gli spin con probabilità 1/2.

# %%
class RandomInvertLayer(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
      super().__init__(**kwargs)

    def call(self, inputs):
      samples = 2*tf.random.categorical(tf.math.log([[0.5, 0.5]]), tf.shape(inputs)[0])-1

      # Reshape b with dim_array and perform elementwise multiplication with 
      # broadcasting along the singleton dimensions for the final output
      samples = tf.reshape(samples, [-1,  1,  1,  1])
      return inputs * tf.cast(samples, "float32")

# %% [markdown]
# Per assicurarmi che l'output finale sia composto solo da 1 o -1, aggiungo un layer apposito.

# %%
class RoundLayer(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
      super().__init__(**kwargs)

    def call(self, inputs):
      up = tf.greater(inputs, 0)
      return 2*tf.cast(up, "int32")-1

# %%
temp_input = layers.Input(shape=(NUM_TEMP_CLASSES,), name="G_Temp_Input")

latent_vector = layers.Input(shape=(LATENT_DIM,), name="G_Latent_Input")

x = g_model([temp_input, latent_vector])
x = RandomInvertLayer()(x)
x = RoundLayer()(x)
final_gen = keras.models.Model([temp_input, latent_vector], x)

# %% [markdown]
# Visualizzo varie configurazioni generate, variando la classe di temperatura da sinistra verso destra.

# %%
classes = tf.one_hot(range(NUM_TEMP_CLASSES), NUM_TEMP_CLASSES)

fig, axs = plt.subplots(10, NUM_TEMP_CLASSES, figsize=(10, 10))
for i in range(10):
  for j in range(NUM_TEMP_CLASSES):
    latent = tf.random.normal(shape=(NUM_TEMP_CLASSES, LATENT_DIM))
    generated_images = final_gen([classes, latent])
    img = generated_images[j].numpy().round().reshape(28, 28)
    axs[i][j].imshow(img)
    axs[i][j].set(xticks=[], yticks=[])

# %% [markdown]
# Genero 100 configurazioni con temperature casuali.

# %%
randint = np.random.randint(0, high=10, size=10000)
classes = tf.one_hot(randint, NUM_TEMP_CLASSES)

latent = tf.random.normal(shape=(10000, LATENT_DIM))
generated_images = final_gen([classes, latent]).numpy().round()

# %% [markdown]
# Plotto i valori della magnetizzazione dei campioni generati in funzione della classe di temperatura.

# %%
magn = np.mean(generated_images, axis=(1, 2))
plt.scatter(randint, magn)
plt.xlabel("Temperature Class")
plt.ylabel("Mean Magnetization")
plt.title("Generated Configurations")
plt.show()

# %% [markdown]
# Confronto con la distribuzione originale.

# %%
orig_magn = np.mean(conf, axis=(1,2))
plt.scatter(label, orig_magn)
plt.xlabel("Temperature Class")
plt.ylabel("Mean Magnetization")
plt.title("Original Dataset")
plt.show()

# %% [markdown]
# Si vede che la GAN genera configurazioni anche migliori del dataset di partenza, poiché non ha acquisito i suoi difetti a basse temperature.

# %% [markdown]
# Visualizzo i due istogrammi della magnetizzazione a confronto.

# %%
plt.close()
plt.hist([magn.reshape(-1), orig_magn.reshape(-1)], label=['fake', 'original'])
plt.legend(loc='upper left')
plt.ylabel("Count")
plt.xlabel("Mean Magnetization")
plt.show()
