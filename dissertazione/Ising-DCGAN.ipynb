# %% [markdown]
# <a href="https://colab.research.google.com/github/raeubaen/ml/blob/master/Ising-DCGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import models & layers from TF/keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# tensor manipulation library
import numpy as np
# plotting library
import matplotlib.pyplot as plt

# plot style parameters
plt.style.use('ggplot')
plt.rcParams['axes.facecolor'] = '#f7f9fc'
from sklearn.model_selection import train_test_split
# Out:
# Collecting plot_model
#   Downloading https://files.pythonhosted.org/packages/62/b8/0967e30391a7c07002c5e7bca868763dcfd26808dcb13aba052a737aa01d/plot_model-0.20-py3-none-any.whl
# Installing collected packages: plot-model
# Successfully installed plot-model-0.20

# %% [markdown]
# Scarico i file con configurazioni (10000 array 28x28) e temperature.

# %%
# dataset download
# !wget https://raw.githubusercontent.com/raeubaen/ml/master/dissertazione/conf.dat
# !wget https://raw.githubusercontent.com/raeubaen/ml/master/dissertazione/label.dat

# %%
# reading configurations and temperatures into numpy 
# (10k elements with 28x28 spin configuration)
conf, temp = np.loadtxt('conf.dat'), np.loadtxt('ising2_label.dat')

# %% [markdown]
# Le temperature verranno divise in 10 classi da 0.5 ciascuna e verranno codificate in vettori one-hot.

# %%
BATCH_SIZE = 64
IMG_SHAPE = (28, 28, 1)
NUM_TEMP_CLASSES = 10
LATENT_DIM = 128

# reshaping configurations into matrix form and specifying dtype
conf = conf.reshape(-1, *IMG_SHAPE).astype('float32')
label = (temp.reshape(-1, 1)*2).astype("int32")

one_hot_temp = keras.utils.to_categorical(label)

# %% [markdown]
# Inserisco i dati in un dataset Tensorflow.

# %%
# converting data (conf and temperatures) into tensorflow Dataset
dataset = tf.data.Dataset.from_tensor_slices((conf, one_hot_temp))
# shuffling and prefetching
dataset = dataset.shuffle(buffer_size=4096).batch(BATCH_SIZE).prefetch(32)

# %% [markdown]
# Costruisco il discriminatore, che prende in input gli array delle configurazioni ed il vettore one-hot che rappresenta la classe di temperatura.

# %%
def get_discriminator_model():

    temp_input = layers.Input(shape=(NUM_TEMP_CLASSES,), name="D_Temp_Input")

    t = layers.Dense(28*28, name="D_temp_Dense")(temp_input)
    t = layers.LeakyReLU(name="D_temp_LReLU")(t)
    t = layers.Reshape(IMG_SHAPE, name="D_temp_Reshape")(t)

    img_input = layers.Input(shape=IMG_SHAPE, name="D_Image_Input")
    x = layers.Concatenate(name="D_Concatenate")([t, img_input])

    x = layers.Conv2D(64, (5, 5), strides=(2, 2), padding='same', 
                      input_shape=IMG_SHAPE, name="D_Conv2D_1")(x)
    x = layers.LeakyReLU(name="D_LReLu_1")(x)
    x = layers.Dropout(0.3, name="D_DropOut_1")(x)

    x = layers.Conv2D(128, (5, 5), strides=(2, 2), 
                      padding='same', name="D_Conv2D_2")(x)
    x = layers.LeakyReLU(name="D_LReLu_2")(x)
    x = layers.Dropout(0.3, name="D_DropOut_2")(x)

    x = layers.Flatten(name="D_Final_Flatten")(x)
    x = layers.Dense(1, name="D_Final_Dense", activation="sigmoid")(x)

    model = keras.models.Model([img_input, temp_input], x, name="discriminator")
    return model

d_model = get_discriminator_model()

# %% [markdown]
# Definisco il generatore, che prende in input il vettore latente (di dimensione 128) e la classe di temperatura come one-hot.

# %%
def get_generator_model():

    temp_input = layers.Input(shape=(NUM_TEMP_CLASSES,), name="G_Temp_Input")

    latent_vector = layers.Input(shape=(LATENT_DIM,), name="G_Latent_Input")

    x = layers.Concatenate(name="G_Concatenate")([latent_vector, temp_input])

    x = layers.Dense(7*7*256, use_bias=False, 
                     input_shape=(2*LATENT_DIM,), name="G_Dense_1")(x)
    x = layers.BatchNormalization(name="G_BM_1")(x)
    x = layers.LeakyReLU(name="G_LReLU_1")(x)

    x = layers.Reshape((7, 7, 256), name="G_Reshape")(x)
    
    x = layers.Conv2DTranspose(128, (4, 4), strides=(1, 1), padding='same', 
                               use_bias=False, name="G_Conv2DTranspose_1")(x)
    x = layers.BatchNormalization(name="G_BM_2")(x)
    x = layers.LeakyReLU(name="G_LReLU_2")(x)

    x = layers.Conv2DTranspose(64, (4, 4), strides=(2, 2), padding='same', 
                               use_bias=False, name="G_Conv2DTranspose_2")(x)
    x = layers.BatchNormalization(name="G_BM_3")(x)
    x = layers.LeakyReLU(name="G_LReLU_3")(x)

    x = layers.Conv2DTranspose(1, (7, 7), strides=(2, 2), padding='same',
       use_bias=False, activation=tf.tanh, name="G_Final_Conv2DTranspose")(x)

    model = keras.models.Model([temp_input, latent_vector], x, name="generator")
    return model

g_model = get_generator_model()
print(g_model.count_params())
# Out:
# 2440512

# %% [markdown]
# Definisco ed alleno il regressore, che prende in input una configurazione e ne restituisce la classe di temperatura come one-hot.

# %%
def get_regressor_model():
  #modello da https://github.com/raeubaen/ml/blob/master/NB_CNN_LC3_2020.ipynb
  inputs = keras.Input(shape=(28,28,1))

  data_augmentation = keras.Sequential([
    keras.layers.experimental.preprocessing.RandomFlip()
  ], name='DataAugm')

  activation = "relu"

  x = data_augmentation(inputs)

  layer_with_activation = lambda name, x: \
      keras.layers.ReLU(name=name)(x)

  ks = 2
  f1 = 64
  x = keras.layers.Conv2D(f1, kernel_size=(ks,ks), name='Conv_1')(x)
  x = layer_with_activation(f'{activation}_1', x)
  x = keras.layers.MaxPooling2D((2,2), name='MaxPool_1')(x)
  x = keras.layers.Conv2D(f1, kernel_size=(ks,ks), name='Conv_2')(x)
  x = layer_with_activation(f'{activation}_2', x)
  x = keras.layers.MaxPooling2D((2,2), name='MaxPool_2')(x)

  x = keras.layers.Conv2D(f1, kernel_size=(ks,ks), name='Conv_3')(x)
  x = layer_with_activation(f'{activation}_3', x)

  x = keras.layers.Flatten(name='Flatten')(x)

  dense_n = 64
  x = keras.layers.Dense(dense_n, name='Dense_1')(x)
  x = layer_with_activation(f'{activation}_dense_1', x)
  x = keras.layers.Dense(dense_n, name='Dense_2')(x)
  x = layer_with_activation(f'{activation}_dense_2', x)
  x = keras.layers.Dense(dense_n, name='Dense_3')(x)
  x = layer_with_activation(f'{activation}_dense_3', x)
  outputs = keras.layers.Dense(NUM_TEMP_CLASSES, name='Output', activation="softmax")(x)

  model = keras.Model(inputs=inputs, outputs=outputs)
  
  model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=8e-4),
        loss='categorical_crossentropy',
        metrics=['accuracy'])
  return model

r_model = get_regressor_model()
cbk = [keras.callbacks.ModelCheckpoint(
           'r.hdf5', save_best_only=True, monitor='val_accuracy', mode='max'
           )]

out = train_test_split(conf, one_hot_temp, test_size=0.1)
train_conf, test_conf, train_one_hot_temp, test_one_hot_temp = out
r_model.fit(train_conf, train_one_hot_temp, 
            epochs=30, validation_split=0.1, callbacks=cbk)
# Out:
# Epoch 1/30
# 254/254 [==============================] - 2s 9ms/step - loss: 1.3067 - accuracy: 0.4138 - val_loss: 0.9889 - val_accuracy: 0.5322
# Epoch 2/30
# 254/254 [==============================] - 2s 8ms/step - loss: 0.9660 - accuracy: 0.5375 - val_loss: 0.8509 - val_accuracy: 0.6078
# Epoch 3/30
# 254/254 [==============================] - 2s 8ms/step - loss: 0.9100 - accuracy: 0.5693 - val_loss: 0.8452 - val_accuracy: 0.6222
# Epoch 4/30
# 254/254 [==============================] - 2s 8ms/step - loss: 0.8868 - accuracy: 0.5733 - val_loss: 0.9453 - val_accuracy: 0.5667
# Epoch 5/30
# 254/254 [==============================] - 2s 8ms/step - loss: 0.8471 - accuracy: 0.6027 - val_loss: 0.9094 - val_accuracy: 0.5822
# Epoch 6/30
# 254/254 [==============================] - 2s 8ms/step - loss: 0.8356 - accuracy: 0.5973 - val_loss: 0.8594 - val_accuracy: 0.6100
# Epoch 7/30
# 254/254 [==============================] - 2s 7ms/step - loss: 0.8184 - accuracy: 0.6067 - val_loss: 0.8783 - val_accuracy: 0.5622
# Epoch 8/30
# 254/254 [==============================] - 2s 7ms/step - loss: 0.8207 - accuracy: 0.6088 - val_loss: 0.8606 - val_accuracy: 0.5867
# Epoch 9/30
# 254/254 [==============================] - 2s 7ms/step - loss: 0.8028 - accuracy: 0.6220 - val_loss: 0.8653 - val_accuracy: 0.6078
# Epoch 10/30
# 254/254 [==============================] - 2s 8ms/step - loss: 0.8091 - accuracy: 0.6142 - val_loss: 0.8454 - val_accuracy: 0.6211
# Epoch 11/30
# 254/254 [==============================] - 2s 8ms/step - loss: 0.8122 - accuracy: 0.6123 - val_loss: 0.7839 - val_accuracy: 0.6300
# Epoch 12/30
# 254/254 [==============================] - 2s 7ms/step - loss: 0.7987 - accuracy: 0.6156 - val_loss: 0.8251 - val_accuracy: 0.6133
# Epoch 13/30
# 254/254 [==============================] - 2s 7ms/step - loss: 0.8020 - accuracy: 0.6177 - val_loss: 0.7863 - val_accuracy: 0.6233
# Epoch 14/30
# 254/254 [==============================] - 2s 8ms/step - loss: 0.7935 - accuracy: 0.6230 - val_loss: 0.7562 - val_accuracy: 0.6489
# Epoch 15/30
# 254/254 [==============================] - 2s 8ms/step - loss: 0.7726 - accuracy: 0.6347 - val_loss: 0.7990 - val_accuracy: 0.6378
# Epoch 16/30
# 254/254 [==============================] - 2s 7ms/step - loss: 0.7732 - accuracy: 0.6319 - val_loss: 0.7584 - val_accuracy: 0.6211
# Epoch 17/30
# 254/254 [==============================] - 2s 7ms/step - loss: 0.7736 - accuracy: 0.6321 - val_loss: 0.8411 - val_accuracy: 0.6078
# Epoch 18/30
# 254/254 [==============================] - 2s 7ms/step - loss: 0.7824 - accuracy: 0.6295 - val_loss: 0.8078 - val_accuracy: 0.6411
# Epoch 19/30
# 254/254 [==============================] - 2s 8ms/step - loss: 0.7741 - accuracy: 0.6312 - val_loss: 0.7671 - val_accuracy: 0.6411
# Epoch 20/30
# 254/254 [==============================] - 2s 7ms/step - loss: 0.7505 - accuracy: 0.6459 - val_loss: 0.7711 - val_accuracy: 0.6378
# Epoch 21/30
# 254/254 [==============================] - 2s 8ms/step - loss: 0.7504 - accuracy: 0.6443 - val_loss: 0.7787 - val_accuracy: 0.6344
# Epoch 22/30
# 254/254 [==============================] - 2s 7ms/step - loss: 0.7385 - accuracy: 0.6504 - val_loss: 0.7650 - val_accuracy: 0.6356
# Epoch 23/30
# 254/254 [==============================] - 2s 7ms/step - loss: 0.7498 - accuracy: 0.6417 - val_loss: 0.7990 - val_accuracy: 0.6178
# Epoch 24/30
# 254/254 [==============================] - 2s 7ms/step - loss: 0.7459 - accuracy: 0.6456 - val_loss: 0.8048 - val_accuracy: 0.6256
# Epoch 25/30
# 254/254 [==============================] - 2s 7ms/step - loss: 0.7409 - accuracy: 0.6456 - val_loss: 0.9326 - val_accuracy: 0.5511
# Epoch 26/30
# 254/254 [==============================] - 2s 8ms/step - loss: 0.7452 - accuracy: 0.6473 - val_loss: 0.7791 - val_accuracy: 0.6022
# Epoch 27/30
# 254/254 [==============================] - 2s 7ms/step - loss: 0.7420 - accuracy: 0.6388 - val_loss: 0.7757 - val_accuracy: 0.6300
# Epoch 28/30
# 254/254 [==============================] - 2s 7ms/step - loss: 0.7245 - accuracy: 0.6468 - val_loss: 0.8032 - val_accuracy: 0.6189
# Epoch 29/30
# 254/254 [==============================] - 2s 7ms/step - loss: 0.7420 - accuracy: 0.6530 - val_loss: 0.8117 - val_accuracy: 0.6300
# Epoch 30/30
# 254/254 [==============================] - 2s 7ms/step - loss: 0.7350 - accuracy: 0.6528 - val_loss: 0.8264 - val_accuracy: 0.6356

# %%
r_model = keras.models.load_model("r.hdf5")
r_model.evaluate(test_conf, test_one_hot_temp)
# Out:
# 32/32 [==============================] - 0s 5ms/step - loss: 0.7648 - accuracy: 0.6480
# [0.7648411989212036, 0.6480000019073486]

# %% [markdown]
# Definisco un modello Keras custom, con un subclassing da `keras.Model`.
# In particolare distinguo tre modalità di allenamento in base all'input dato al discriminatore
# *   A: (immagini reali, temperature reali) -> target 1, (immagini fake, temperature usate per generarle)-> target 0
#
# *   B: (immagini reali, temperature reali) -> target 1, (immagini reali, temperature random)-> target 0, (immagini fake, temperature usate per generarle) -> target 0
#
# *   C: (immagini reali, temperature reali) -> target 1, (immagini reali, temperature random)-> target 0, (immagini fake, temperature ottenute dal regressore sulle immagini fake)-> target 0

# %%
# Modello DCGAN: implementiamo un keras.Model custom
class DCGAN(keras.Model):
    def __init__(self, discriminator, generator, regressor, latent_dim, mode=None):
        super().__init__()
        self.discriminator = discriminator
        self.generator = generator
        self.regressor = regressor
        self.latent_dim = latent_dim
        self.mode = mode

    # funzione per la compilazione
    def compile(self, d_optimizer, g_optimizer, loss_fn):
        super().compile()
        self.d_optimizer = d_optimizer
        self.g_optimizer = g_optimizer
        self.loss_fn = loss_fn

    def train_step(self, train_batch):
        if isinstance(train_batch, tuple): #verifica che l'input isa una python tuple (numpy tensor)
            real_images, real_classes = train_batch

        # 1) campiona un batch di punti random nello spazio latente: z
        batch_size = tf.shape(real_images)[0]
        rand_classes = tf.one_hot(
            tf.random.uniform(
                shape=(batch_size,), 
                maxval=NUM_TEMP_CLASSES, 
                dtype=tf.int32
            ),
            NUM_TEMP_CLASSES,
        )
        rand_latent = tf.random.normal(shape=(batch_size, self.latent_dim))

        # 2) usa il generatore per creare dai vettori latenti immagini fake: immagine = G(z)
        generated_images = self.generator([rand_classes, rand_latent])
        
        # 3) determina la temperatura delle immagini generate grazie alla rete ausiliaria

        if self.mode == "A":
            # 4) combina le immagini fake con quelle reali 
            combined_images = tf.concat([
                            real_images, generated_images,# real_images,
            ], axis=0)

            combined_classes = tf.concat([
                            real_classes, rand_classes,# rand_classes,
            ], axis=0)

            # 5) assegna le label corrette (fae vs reale)
            labels = tf.concat([
                tf.ones((batch_size, 1)),  #immagini reali, temperature reali
                tf.zeros((batch_size, 1)), #immagini generate, temperature corrispondenti
                #tf.zeros((batch_size, 1)), #immagini reali, temperature no
            ], axis=0)

        if self.mode == "B":
            generated_classes = self.regressor(generated_images)

            # 4) combina le immagini fake con quelle reali 
            combined_images = tf.concat([
                             real_images, generated_images, real_images,
            ], axis=0)

            combined_classes = tf.concat([
                             real_classes, rand_classes, rand_classes,
            ], axis=0)

            # 5) assegna le label corrette (fae vs reale)
            labels = tf.concat([
                tf.ones((batch_size, 1)),  #immagini reali, temperature reali
                tf.zeros((batch_size, 1)), #immagini generate, temperature corrispondenti
                tf.zeros((batch_size, 1)), #immagini reali, temperature no
            ], axis=0)

        if self.mode == "C":
            generated_classes = self.regressor(generated_images)
            # 4) combina le immagini fake con quelle reali 
            combined_images = tf.concat([
                             real_images, generated_images, real_images,
            ], axis=0)

            combined_classes = tf.concat([
                              real_classes, generated_classes, rand_classes,
            ], axis=0)

            # 5) assegna le label corrette (fae vs reale)
            labels = tf.concat([
                tf.ones((batch_size, 1)),  #immagini reali, temperature reali
                tf.zeros((batch_size, 1)), #immagini generate, temperature corrispondenti
                tf.zeros((batch_size, 1)), #immagini reali, temperature no
            ], axis=0)

        # 6) Trucco per diminuire la probabilità di collasso della rete (si aggiunge un po' di rumore random alle label) 
        labels += 0.05 * tf.random.uniform(tf.shape(labels))

        # 7) Training del discriminatore D
        with tf.GradientTape() as tape: #autograd
            predictions = self.discriminator(
                [combined_images, combined_classes]) #predizione = D(immagini)
            d_loss = self.loss_fn(labels, predictions) #calcolo loss
        grads = tape.gradient(d_loss, self.discriminator.trainable_weights) #backprop
        self.d_optimizer.apply_gradients(
            zip(grads, self.discriminator.trainable_weights) #aggiornamento pesi
        )

        # 8) crea un vettore di label corrispondenti a tutte immagii reali
        misleading_labels = tf.ones((batch_size, 1))

        # 9) Training del generatore (non si devono aggiornare ovviamente i pesi del discriminatore)
        with tf.GradientTape() as tape:
            generated_images = self.generator([rand_classes, rand_latent])
            predictions = self.discriminator([generated_images, rand_classes]) #predizione = D(G(z))
            g_loss = self.loss_fn(misleading_labels, predictions) #calcolo loss
        grads = tape.gradient(g_loss, self.generator.trainable_weights) #backprop
        self.g_optimizer.apply_gradients(zip(grads, self.generator.trainable_weights)) #aggiornamento pesi

        return {"d_loss": d_loss, "g_loss": g_loss}

# %% [markdown]
# Definisco una callback custom, con un subclassing di `keras.callbacks.Callback`,
# che alla fine di ogni epoca salva come immagine un set di configurazioni generate (una per ciascuna classe di temperatura).

# %%
# custom callback to save generated images peridoically during training
class GANMonitor(keras.callbacks.Callback):
    def __init__(self, num_img=11, latent_dim=128, norma=1.0):
        self.num_img = num_img
        self.latent_dim = latent_dim
        self.norma = norma

    def on_epoch_end(self, epoch, logs=None):
        classes = tf.one_hot(range(self.num_img), NUM_TEMP_CLASSES)
        latent = tf.random.normal(shape=(self.num_img, self.latent_dim))
        generated_images = self.model.generator([classes, latent])
        generated_images = generated_images * self.norma
        fig, axs = plt.subplots(1, self.num_img, figsize=(18, 5))
        for i in range(self.num_img):
            img = generated_images[i].numpy().reshape(28, 28)
            axs[i].imshow(img)
        fig.savefig(f"{epoch}.png")
        plt.close()

# %% [markdown]
# Come ottimizzatore utilizzo ADAM, con $\eta=0.0002,\,\beta=0.5$ (best-practice per le GAN).

# %%
# Training della GAN

# Ottimizzatori di G e D
# learning_rate=0.0002, beta_1=0.5 are recommened
generator_optimizer = keras.optimizers.Adam(
    learning_rate=0.0002, beta_1=0.5, beta_2=0.9)

discriminator_optimizer = keras.optimizers.Adam(
    learning_rate=0.0002, beta_1=0.5, beta_2=0.9)
# Loss function
gan_loss = keras.losses.BinaryCrossentropy(from_logits=True)

# Callbacks
cbk = GANMonitor(num_img=NUM_TEMP_CLASSES, latent_dim=LATENT_DIM, norma=255)

# %% [markdown]
# Eseguo il training della GAN, con le tre modalità A, B e C in sequenza (300 epoche ciascuna).

# %%
for mode in ["C"]:
  # Istanziamento modello
  gan = DCGAN(discriminator=d_model, generator=g_model, regressor=r_model, 
              latent_dim=LATENT_DIM, mode=mode)

  # Compilazione
  gan.compile(d_optimizer=discriminator_optimizer,
      g_optimizer=generator_optimizer,
      loss_fn=gan_loss,
  )

  gan.fit(dataset, epochs=300, batch_size=64, callbacks=[cbk])
# Out:
# Epoch 1/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5987 - g_loss: 0.3548
# Epoch 2/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.6001 - g_loss: 0.3558
# Epoch 3/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5979 - g_loss: 0.3565
# Epoch 4/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5989 - g_loss: 0.3561
# Epoch 5/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.6003 - g_loss: 0.3550
# Epoch 6/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5988 - g_loss: 0.3585
# Epoch 7/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5991 - g_loss: 0.3579
# Epoch 8/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5985 - g_loss: 0.3556
# Epoch 9/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5972 - g_loss: 0.3543
# Epoch 10/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5996 - g_loss: 0.3589
# Epoch 11/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5986 - g_loss: 0.3577
# Epoch 12/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5981 - g_loss: 0.3557
# Epoch 13/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5984 - g_loss: 0.3574
# Epoch 14/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5981 - g_loss: 0.3561
# Epoch 15/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5983 - g_loss: 0.3566
# Epoch 16/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5979 - g_loss: 0.3591
# Epoch 17/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5984 - g_loss: 0.3568
# Epoch 18/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5971 - g_loss: 0.3567
# Epoch 19/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.6002 - g_loss: 0.3534
# Epoch 20/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5968 - g_loss: 0.3573
# Epoch 21/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5974 - g_loss: 0.3562
# Epoch 22/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5988 - g_loss: 0.3573
# Epoch 23/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5996 - g_loss: 0.3550
# Epoch 24/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5986 - g_loss: 0.3579
# Epoch 25/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5974 - g_loss: 0.3539
# Epoch 26/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5993 - g_loss: 0.3552
# Epoch 27/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5974 - g_loss: 0.3542
# Epoch 28/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5975 - g_loss: 0.3553
# Epoch 29/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5995 - g_loss: 0.3567
# Epoch 30/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5982 - g_loss: 0.3564
# Epoch 31/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5986 - g_loss: 0.3532
# Epoch 32/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5991 - g_loss: 0.3553
# Epoch 33/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5979 - g_loss: 0.3560
# Epoch 34/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5987 - g_loss: 0.3552
# Epoch 35/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5985 - g_loss: 0.3544
# Epoch 36/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5978 - g_loss: 0.3565
# Epoch 37/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5980 - g_loss: 0.3523
# Epoch 38/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5986 - g_loss: 0.3572
# Epoch 39/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5991 - g_loss: 0.3566
# Epoch 40/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5985 - g_loss: 0.3542
# Epoch 41/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5972 - g_loss: 0.3575
# Epoch 42/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5983 - g_loss: 0.3564
# Epoch 43/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.6000 - g_loss: 0.3559
# Epoch 44/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5985 - g_loss: 0.3536
# Epoch 45/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5980 - g_loss: 0.3569
# Epoch 46/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.6003 - g_loss: 0.3566
# Epoch 47/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5977 - g_loss: 0.3587
# Epoch 48/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5977 - g_loss: 0.3572
# Epoch 49/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5980 - g_loss: 0.3558
# Epoch 50/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5974 - g_loss: 0.3543
# Epoch 51/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5997 - g_loss: 0.3550
# Epoch 52/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5989 - g_loss: 0.3541
# Epoch 53/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5982 - g_loss: 0.3544
# Epoch 54/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5980 - g_loss: 0.3560
# Epoch 55/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5977 - g_loss: 0.3547
# Epoch 56/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5973 - g_loss: 0.3573
# Epoch 57/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5970 - g_loss: 0.3566
# Epoch 58/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5990 - g_loss: 0.3555
# Epoch 59/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5992 - g_loss: 0.3535
# Epoch 60/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5988 - g_loss: 0.3582
# Epoch 61/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5970 - g_loss: 0.3548
# Epoch 62/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5972 - g_loss: 0.3583
# Epoch 63/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5971 - g_loss: 0.3567
# Epoch 64/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5980 - g_loss: 0.3542
# Epoch 65/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5973 - g_loss: 0.3536
# Epoch 66/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5978 - g_loss: 0.3550
# Epoch 67/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5981 - g_loss: 0.3572
# Epoch 68/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5988 - g_loss: 0.3568
# Epoch 69/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5964 - g_loss: 0.3556
# Epoch 70/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5982 - g_loss: 0.3560
# Epoch 71/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5979 - g_loss: 0.3565
# Epoch 72/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5990 - g_loss: 0.3545
# Epoch 73/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5963 - g_loss: 0.3534
# Epoch 74/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5990 - g_loss: 0.3545
# Epoch 75/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5965 - g_loss: 0.3568
# Epoch 76/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5977 - g_loss: 0.3543
# Epoch 77/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5980 - g_loss: 0.3559
# Epoch 78/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5966 - g_loss: 0.3549
# Epoch 79/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5996 - g_loss: 0.3548
# Epoch 80/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5975 - g_loss: 0.3535
# Epoch 81/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5986 - g_loss: 0.3539
# Epoch 82/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5982 - g_loss: 0.3563
# Epoch 83/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5974 - g_loss: 0.3563
# Epoch 84/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5980 - g_loss: 0.3567
# Epoch 85/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5980 - g_loss: 0.3537
# Epoch 86/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5982 - g_loss: 0.3516
# Epoch 87/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5985 - g_loss: 0.3571
# Epoch 88/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5978 - g_loss: 0.3584
# Epoch 89/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5979 - g_loss: 0.3555
# Epoch 90/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5992 - g_loss: 0.3548
# Epoch 91/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5990 - g_loss: 0.3566
# Epoch 92/300
# 157/157 [==============================] - 28s 181ms/step - d_loss: 0.5981 - g_loss: 0.3544
# Epoch 93/300
# 157/157 [==============================] - 7s 47ms/step - d_loss: 0.5984 - g_loss: 0.3560
# Epoch 94/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5976 - g_loss: 0.3558
# Epoch 95/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5989 - g_loss: 0.3569
# Epoch 96/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5979 - g_loss: 0.3513
# Epoch 97/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5970 - g_loss: 0.3560
# Epoch 98/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5970 - g_loss: 0.3575
# Epoch 99/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5991 - g_loss: 0.3593
# Epoch 100/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5978 - g_loss: 0.3554
# Epoch 101/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.6003 - g_loss: 0.3577
# Epoch 102/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5983 - g_loss: 0.3574
# Epoch 103/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5966 - g_loss: 0.3525
# Epoch 104/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5981 - g_loss: 0.3562
# Epoch 105/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5981 - g_loss: 0.3588
# Epoch 106/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5971 - g_loss: 0.3549
# Epoch 107/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5975 - g_loss: 0.3542
# Epoch 108/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5993 - g_loss: 0.3527
# Epoch 109/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5982 - g_loss: 0.3551
# Epoch 110/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5985 - g_loss: 0.3537
# Epoch 111/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5974 - g_loss: 0.3586
# Epoch 112/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5989 - g_loss: 0.3550
# Epoch 113/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5974 - g_loss: 0.3514
# Epoch 114/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5971 - g_loss: 0.3529
# Epoch 115/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5987 - g_loss: 0.3588
# Epoch 116/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5972 - g_loss: 0.3563
# Epoch 117/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5982 - g_loss: 0.3529
# Epoch 118/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5974 - g_loss: 0.3542
# Epoch 119/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5982 - g_loss: 0.3542
# Epoch 120/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5978 - g_loss: 0.3545
# Epoch 121/300
# 157/157 [==============================] - 9s 54ms/step - d_loss: 0.5980 - g_loss: 0.3556
# Epoch 122/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5971 - g_loss: 0.3560
# Epoch 123/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5982 - g_loss: 0.3529
# Epoch 124/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5976 - g_loss: 0.3546
# Epoch 125/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5973 - g_loss: 0.3519
# Epoch 126/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5969 - g_loss: 0.3534
# Epoch 127/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5975 - g_loss: 0.3535
# Epoch 128/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5987 - g_loss: 0.3544
# Epoch 129/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5972 - g_loss: 0.3550
# Epoch 130/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5977 - g_loss: 0.3541
# Epoch 131/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5968 - g_loss: 0.3547
# Epoch 132/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5984 - g_loss: 0.3517
# Epoch 133/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5968 - g_loss: 0.3571
# Epoch 134/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5977 - g_loss: 0.3554
# Epoch 135/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5978 - g_loss: 0.3561
# Epoch 136/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5974 - g_loss: 0.3545
# Epoch 137/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5986 - g_loss: 0.3519
# Epoch 138/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5985 - g_loss: 0.3526
# Epoch 139/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5974 - g_loss: 0.3547
# Epoch 140/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5985 - g_loss: 0.3537
# Epoch 141/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5973 - g_loss: 0.3526
# Epoch 142/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5980 - g_loss: 0.3550
# Epoch 143/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5981 - g_loss: 0.3489
# Epoch 144/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5981 - g_loss: 0.3527
# Epoch 145/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5982 - g_loss: 0.3492
# Epoch 146/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5978 - g_loss: 0.3523
# Epoch 147/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5967 - g_loss: 0.3543
# Epoch 148/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5974 - g_loss: 0.3545
# Epoch 149/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5969 - g_loss: 0.3514
# Epoch 150/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5964 - g_loss: 0.3506
# Epoch 151/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5970 - g_loss: 0.3474
# Epoch 152/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5963 - g_loss: 0.3500
# Epoch 153/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5968 - g_loss: 0.3487
# Epoch 154/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5975 - g_loss: 0.3526
# Epoch 155/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5968 - g_loss: 0.3580
# Epoch 156/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5991 - g_loss: 0.3515
# Epoch 157/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5967 - g_loss: 0.3517
# Epoch 158/300
# 157/157 [==============================] - 9s 57ms/step - d_loss: 0.5970 - g_loss: 0.3528
# Epoch 159/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5992 - g_loss: 0.3477
# Epoch 160/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5969 - g_loss: 0.3493
# Epoch 161/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5975 - g_loss: 0.3536
# Epoch 162/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5968 - g_loss: 0.3488
# Epoch 163/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5972 - g_loss: 0.3507
# Epoch 164/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5982 - g_loss: 0.3581
# Epoch 165/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5955 - g_loss: 0.3511
# Epoch 166/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5973 - g_loss: 0.3484
# Epoch 167/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5975 - g_loss: 0.3480
# Epoch 168/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5977 - g_loss: 0.3488
# Epoch 169/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5966 - g_loss: 0.3477
# Epoch 170/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5972 - g_loss: 0.3456
# Epoch 171/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5978 - g_loss: 0.3497
# Epoch 172/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5982 - g_loss: 0.3514
# Epoch 173/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5963 - g_loss: 0.3493
# Epoch 174/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5986 - g_loss: 0.3465
# Epoch 175/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5970 - g_loss: 0.3505
# Epoch 176/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5964 - g_loss: 0.3500
# Epoch 177/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5968 - g_loss: 0.3455
# Epoch 178/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5971 - g_loss: 0.3487
# Epoch 179/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5978 - g_loss: 0.3501
# Epoch 180/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5963 - g_loss: 0.3487
# Epoch 181/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5981 - g_loss: 0.3498
# Epoch 182/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5977 - g_loss: 0.3496
# Epoch 183/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5980 - g_loss: 0.3457
# Epoch 184/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5973 - g_loss: 0.3469
# Epoch 185/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5970 - g_loss: 0.3512
# Epoch 186/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5978 - g_loss: 0.3484
# Epoch 187/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5968 - g_loss: 0.3486
# Epoch 188/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5991 - g_loss: 0.3507
# Epoch 189/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5964 - g_loss: 0.3461
# Epoch 190/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5971 - g_loss: 0.3489
# Epoch 191/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5982 - g_loss: 0.3500
# Epoch 192/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5977 - g_loss: 0.3476
# Epoch 193/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5962 - g_loss: 0.3481
# Epoch 194/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5988 - g_loss: 0.3466
# Epoch 195/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5974 - g_loss: 0.3531
# Epoch 196/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5973 - g_loss: 0.3474
# Epoch 197/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5962 - g_loss: 0.3484
# Epoch 198/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5954 - g_loss: 0.3461
# Epoch 199/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5983 - g_loss: 0.3482
# Epoch 200/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5968 - g_loss: 0.3506
# Epoch 201/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5968 - g_loss: 0.3449
# Epoch 202/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5977 - g_loss: 0.3461
# Epoch 203/300
# 157/157 [==============================] - 9s 60ms/step - d_loss: 0.5969 - g_loss: 0.3475
# Epoch 204/300
# 157/157 [==============================] - 7s 47ms/step - d_loss: 0.5971 - g_loss: 0.3446
# Epoch 205/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5983 - g_loss: 0.3428
# Epoch 206/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5966 - g_loss: 0.3446
# Epoch 207/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5977 - g_loss: 0.3451
# Epoch 208/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5968 - g_loss: 0.3424
# Epoch 209/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5991 - g_loss: 0.3417
# Epoch 210/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5957 - g_loss: 0.3445
# Epoch 211/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5966 - g_loss: 0.3453
# Epoch 212/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5979 - g_loss: 0.3456
# Epoch 213/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5978 - g_loss: 0.3463
# Epoch 214/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5965 - g_loss: 0.3426
# Epoch 215/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5984 - g_loss: 0.3421
# Epoch 216/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5971 - g_loss: 0.3450
# Epoch 217/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5984 - g_loss: 0.3458
# Epoch 218/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5970 - g_loss: 0.3450
# Epoch 219/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5971 - g_loss: 0.3402
# Epoch 220/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5991 - g_loss: 0.3448
# Epoch 221/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5974 - g_loss: 0.3424
# Epoch 222/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5989 - g_loss: 0.3452
# Epoch 223/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5967 - g_loss: 0.3444
# Epoch 224/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5975 - g_loss: 0.3437
# Epoch 225/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5953 - g_loss: 0.3474
# Epoch 226/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5960 - g_loss: 0.3488
# Epoch 227/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5965 - g_loss: 0.3480
# Epoch 228/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5977 - g_loss: 0.3461
# Epoch 229/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5965 - g_loss: 0.3450
# Epoch 230/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5968 - g_loss: 0.3418
# Epoch 231/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5972 - g_loss: 0.3443
# Epoch 232/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5964 - g_loss: 0.3435
# Epoch 233/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5965 - g_loss: 0.3434
# Epoch 234/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5963 - g_loss: 0.3422
# Epoch 235/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5966 - g_loss: 0.3436
# Epoch 236/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5977 - g_loss: 0.3392
# Epoch 237/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5962 - g_loss: 0.3406
# Epoch 238/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5974 - g_loss: 0.3391
# Epoch 239/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5960 - g_loss: 0.3429
# Epoch 240/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5961 - g_loss: 0.3415
# Epoch 241/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5966 - g_loss: 0.3406
# Epoch 242/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5989 - g_loss: 0.3394
# Epoch 243/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5971 - g_loss: 0.3413
# Epoch 244/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5972 - g_loss: 0.3453
# Epoch 245/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5965 - g_loss: 0.3418
# Epoch 246/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5975 - g_loss: 0.3414
# Epoch 247/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5966 - g_loss: 0.3408
# Epoch 248/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5978 - g_loss: 0.3384
# Epoch 249/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5967 - g_loss: 0.3407
# Epoch 250/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5965 - g_loss: 0.3415
# Epoch 251/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5975 - g_loss: 0.3451
# Epoch 252/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5960 - g_loss: 0.3435
# Epoch 253/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5971 - g_loss: 0.3405
# Epoch 254/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5962 - g_loss: 0.3390
# Epoch 255/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5981 - g_loss: 0.3416
# Epoch 256/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5974 - g_loss: 0.3403
# Epoch 257/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5963 - g_loss: 0.3400
# Epoch 258/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5969 - g_loss: 0.3404
# Epoch 259/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5964 - g_loss: 0.3403
# Epoch 260/300
# 157/157 [==============================] - 10s 62ms/step - d_loss: 0.5968 - g_loss: 0.3453
# Epoch 261/300
# 157/157 [==============================] - 7s 47ms/step - d_loss: 0.5975 - g_loss: 0.3420
# Epoch 262/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5974 - g_loss: 0.3394
# Epoch 263/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5967 - g_loss: 0.3409
# Epoch 264/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5978 - g_loss: 0.3380
# Epoch 265/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5971 - g_loss: 0.3354
# Epoch 266/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5977 - g_loss: 0.3449
# Epoch 267/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5971 - g_loss: 0.3392
# Epoch 268/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5966 - g_loss: 0.3392
# Epoch 269/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5980 - g_loss: 0.3404
# Epoch 270/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5968 - g_loss: 0.3390
# Epoch 271/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5962 - g_loss: 0.3380
# Epoch 272/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5975 - g_loss: 0.3370
# Epoch 273/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5982 - g_loss: 0.3360
# Epoch 274/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5967 - g_loss: 0.3384
# Epoch 275/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5975 - g_loss: 0.3353
# Epoch 276/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5971 - g_loss: 0.3357
# Epoch 277/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5971 - g_loss: 0.3408
# Epoch 278/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5948 - g_loss: 0.3408
# Epoch 279/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5967 - g_loss: 0.3369
# Epoch 280/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5972 - g_loss: 0.3368
# Epoch 281/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5976 - g_loss: 0.3385
# Epoch 282/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5975 - g_loss: 0.3388
# Epoch 283/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5959 - g_loss: 0.3392
# Epoch 284/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5970 - g_loss: 0.3391
# Epoch 285/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5970 - g_loss: 0.3364
# Epoch 286/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5973 - g_loss: 0.3383
# Epoch 287/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5972 - g_loss: 0.3406
# Epoch 288/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5984 - g_loss: 0.3397
# Epoch 289/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5958 - g_loss: 0.3417
# Epoch 290/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5964 - g_loss: 0.3385
# Epoch 291/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5967 - g_loss: 0.3366
# Epoch 292/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5957 - g_loss: 0.3369
# Epoch 293/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5984 - g_loss: 0.3387
# Epoch 294/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5982 - g_loss: 0.3365
# Epoch 295/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5973 - g_loss: 0.3370
# Epoch 296/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5962 - g_loss: 0.3398
# Epoch 297/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5965 - g_loss: 0.3452
# Epoch 298/300
# 157/157 [==============================] - 7s 45ms/step - d_loss: 0.5960 - g_loss: 0.3438
# Epoch 299/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5964 - g_loss: 0.3437
# Epoch 300/300
# 157/157 [==============================] - 7s 46ms/step - d_loss: 0.5972 - g_loss: 0.3382

# %% [markdown]
# Per garantire maggiore variabilità al generatore, aggiungo un layer finale che inverte tutti gli spin con probabilità 1/2.

# %%
class RandomInvertLayer(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
      super().__init__(**kwargs)

    def call(self, inputs):
      samples = 2*tf.random.categorical(tf.math.log([[0.5, 0.5]]), tf.shape(inputs)[0])-1

      # Reshape b with dim_array and perform elementwise multiplication with 
      # broadcasting along the singleton dimensions for the final output
      samples = tf.reshape(samples, [-1,  1,  1,  1])
      return inputs * tf.cast(samples, "float32")

# %% [markdown]
# Per assicurarmi che l'output finale sia composto solo da 1 o -1, aggiungo un layer apposito.

# %%
class RoundLayer(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
      super().__init__(**kwargs)

    def call(self, inputs):
      up = tf.greater(inputs, 0)
      return 2*tf.cast(up, "int32")-1

# %%
temp_input = layers.Input(shape=(NUM_TEMP_CLASSES,), name="G_Temp_Input")

latent_vector = layers.Input(shape=(LATENT_DIM,), name="G_Latent_Input")

x = g_model([temp_input, latent_vector])
x = RandomInvertLayer()(x)
x = RoundLayer()(x)
final_gen = keras.models.Model([temp_input, latent_vector], x)

# %% [markdown]
# Visualizzo varie configurazioni generate, variando la classe di temperatura da sinistra verso destra.

# %%
classes = tf.one_hot(range(NUM_TEMP_CLASSES), NUM_TEMP_CLASSES)

fig, axs = plt.subplots(10, NUM_TEMP_CLASSES, figsize=(15, 15))
for i in range(10):
  for j in range(NUM_TEMP_CLASSES):
    latent = tf.random.normal(shape=(NUM_TEMP_CLASSES, LATENT_DIM))
    generated_images = final_gen([classes, latent])

    img = generated_images[j].numpy().round().reshape(28, 28)
    axs[i][j].imshow(img, vmin=-1, vmax=1)

    axs[i][j].set(xticks=[], yticks=[])

# %% [markdown]
# Genero 100 configurazioni con temperature casuali.

# %%
randint = np.random.randint(0, high=10, size=10000)
classes = tf.one_hot(randint, NUM_TEMP_CLASSES)

latent = tf.random.normal(shape=(10000, LATENT_DIM))
generated_images = final_gen([classes, latent]).numpy().round()

# %% [markdown]
# Plotto i valori della magnetizzazione dei campioni generati in funzione della classe di temperatura.

# %%
magn = np.mean(generated_images, axis=(1, 2))
plt.scatter(randint, magn)
plt.xlabel("Temperature Class")
plt.ylabel("Mean Magnetization")
plt.title("Generated Configurations")
plt.show()

# %% [markdown]
# Confronto con la distribuzione originale.

# %%
orig_magn = np.mean(conf, axis=(1,2))
plt.scatter(label, orig_magn)
plt.xlabel("Temperature Class")
plt.ylabel("Mean Magnetization")
plt.title("Original Dataset")
plt.show()

# %% [markdown]
# Si vede che la GAN genera configurazioni anche migliori del dataset di partenza, poiché non ha acquisito i suoi difetti a basse temperature.

# %% [markdown]
# Visualizzo i due istogrammi della magnetizzazione a confronto.

# %%
plt.close()
plt.hist([magn.reshape(-1), orig_magn.reshape(-1)], label=['fake', 'original'])
plt.legend(loc='upper left')
plt.ylabel("Count")
plt.xlabel("Mean Magnetization")
plt.show()
