# %% [markdown]
# <a href="https://colab.research.google.com/github/raeubaen/ml/blob/master/Conditional%20GAN-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import models & layers from TF/keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# tensor manipulation library
import numpy as np
# plotting library
import matplotlib.pyplot as plt
# !pip install plot_model
from plot_model import plot_model
# disabling eager (slower) execution
#from tensorflow.python.framework.ops import disable_eager_execution
#disable_eager_execution()
from sklearn.model_selection import train_test_split
# Out:
# Collecting plot_model
#   Downloading https://files.pythonhosted.org/packages/62/b8/0967e30391a7c07002c5e7bca868763dcfd26808dcb13aba052a737aa01d/plot_model-0.20-py3-none-any.whl
# Installing collected packages: plot-model
# Successfully installed plot-model-0.20

# %%
# dataset download
# !wget http://www.roma1.infn.it/~giagu/datasets/ising2_conf.dat
# !wget http://www.roma1.infn.it/~giagu/datasets/ising2_label.dat

# reading configurations and temperatures into numpy 
# (10k elements with 28x28 spin configuration)
conf, temp = np.loadtxt('ising2_conf.dat'), np.loadtxt('ising2_label.dat')
# Out:
# --2020-06-03 10:28:25--  http://www.roma1.infn.it/~giagu/datasets/ising2_conf.dat
# Resolving www.roma1.infn.it (www.roma1.infn.it)... 141.108.26.1, 141.108.26.150
# Connecting to www.roma1.infn.it (www.roma1.infn.it)|141.108.26.1|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19060775 (18M)
# Saving to: ‘ising2_conf.dat’
#
# ising2_conf.dat     100%[===================>]  18.18M   734KB/s    in 34s
#
# 2020-06-03 10:29:00 (547 KB/s) - ‘ising2_conf.dat’ saved [19060775/19060775]
#
# --2020-06-03 10:29:02--  http://www.roma1.infn.it/~giagu/datasets/ising2_label.dat
# Resolving www.roma1.infn.it (www.roma1.infn.it)... 141.108.26.1, 141.108.26.150
# Connecting to www.roma1.infn.it (www.roma1.infn.it)|141.108.26.1|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 81025 (79K)
# Saving to: ‘ising2_label.dat’
#
# ising2_label.dat    100%[===================>]  79.13K   125KB/s    in 0.6s
#
# 2020-06-03 10:29:04 (125 KB/s) - ‘ising2_label.dat’ saved [81025/81025]

# %%
BATCH_SIZE = 64
IMG_SHAPE = (28, 28, 1)
NUM_TEMP_CLASSES = 11
EMBEDDING_DIM = 64
LATENT_DIM = 128

# %%
# reshaping configurations into matrix form and specifying dtype
conf = conf.reshape(-1, *IMG_SHAPE).astype('float32')
label = (temp.reshape(-1, 1)*2).round().astype("int32")

one_hot_temp = keras.utils.to_categorical(label)
# converting data (conf and temperatures) into tensorflow Dataset
dataset = tf.data.Dataset.from_tensor_slices((conf, one_hot_temp))
# shuffling and prefetching
dataset = dataset.shuffle(buffer_size=1024).batch(BATCH_SIZE).prefetch(32)

# %%
def get_discriminator_model():

    temp_input = layers.Input(shape=(NUM_TEMP_CLASSES,), name="D_Temp_Input")

    t = layers.Dense(28*28, name="D_temp_Dense")(temp_input)
    t = layers.LeakyReLU(name="D_temp_LReLU")(t)
    t = layers.Reshape(IMG_SHAPE, name="D_temp_Reshape")(t)

    img_input = layers.Input(shape=IMG_SHAPE, name="D_Image_Input")
    x = layers.Concatenate(name="D_Concatenate")([t, img_input])

    x = layers.Conv2D(64, (5, 5), strides=(2, 2), padding='same', 
                      input_shape=IMG_SHAPE, name="D_Conv2D_1")(x)
    x = layers.LeakyReLU(name="D_LReLu_1")(x)
    x = layers.Dropout(0.3, name="D_DropOut_1")(x)

    x = layers.Conv2D(128, (5, 5), strides=(2, 2), 
                      padding='same', name="D_Conv2D_2")(x)
    x = layers.LeakyReLU(name="D_LReLu_2")(x)
    x = layers.Dropout(0.3, name="D_DropOut_2")(x)

    x = layers.Flatten(name="D_Final_Flatten")(x)
    x = layers.Dense(1, name="D_Final_Dense", activation="sigmoid")(x)

    model = keras.models.Model([img_input, temp_input], x, name="discriminator")
    return model

d_model = get_discriminator_model()
plot_model(d_model, 
  dpi=60, color=True, style=1, to_file="d_model.png", show_layer_names=True)

# %%
def get_generator_model():

    temp_input = layers.Input(shape=(NUM_TEMP_CLASSES,), name="G_Temp_Input")

    latent_vector = layers.Input(shape=(LATENT_DIM,), name="G_Latent_Input")

    x = layers.Concatenate(name="G_Concatenate")([latent_vector, temp_input])

    x = layers.Dense(7*7*256, use_bias=False, 
                     input_shape=(2*LATENT_DIM,), name="G_Dense_1")(x)
    x = layers.BatchNormalization(name="G_BM_1")(x)
    x = layers.LeakyReLU(name="G_LReLU_1")(x)

    x = layers.Reshape((7, 7, 256), name="G_Reshape")(x)
    
    x = layers.Conv2DTranspose(128, (4, 4), strides=(1, 1), padding='same', 
                               use_bias=False, name="G_Conv2DTranspose_1")(x)
    x = layers.BatchNormalization(name="G_BM_2")(x)
    x = layers.LeakyReLU(name="G_LReLU_2")(x)

    x = layers.Conv2DTranspose(64, (4, 4), strides=(2, 2), padding='same', 
                               use_bias=False, name="G_Conv2DTranspose_2")(x)
    x = layers.BatchNormalization(name="G_BM_3")(x)
    x = layers.LeakyReLU(name="G_LReLU_3")(x)

    x = layers.Conv2DTranspose(1, (7, 7), strides=(2, 2), padding='same',
       use_bias=False, activation=tf.tanh, name="G_Final_Conv2DTranspose")(x)

    model = keras.models.Model([temp_input, latent_vector], x, name="generator")
    return model

g_model = get_generator_model()
print(g_model.count_params())
plot_model(g_model, 
  dpi=60, color=True, style=1, to_file="g_model.png", show_layer_names=True)
# Out:
# 2453056

# %%
def get_regressor_model():
  #modello da https://github.com/raeubaen/ml/blob/master/NB_CNN_LC3_2020.ipynb
  inputs = keras.Input(shape=(28,28,1))

  data_augmentation = keras.Sequential([
    keras.layers.experimental.preprocessing.RandomFlip()
  ], name='DataAugm')

  activation = "relu"

  x = data_augmentation(inputs)

  layer_with_activation = lambda name, x: \
      keras.layers.ReLU(name=name)(x)

  ks = 2
  f1 = 64
  x = keras.layers.Conv2D(f1, kernel_size=(ks,ks), name='Conv_1')(x)
  x = layer_with_activation(f'{activation}_1', x)
  x = keras.layers.MaxPooling2D((2,2), name='MaxPool_1')(x)
  x = keras.layers.Conv2D(f1, kernel_size=(ks,ks), name='Conv_2')(x)
  x = layer_with_activation(f'{activation}_2', x)
  x = keras.layers.MaxPooling2D((2,2), name='MaxPool_2')(x)

  x = keras.layers.Conv2D(f1, kernel_size=(ks,ks), name='Conv_3')(x)
  x = layer_with_activation(f'{activation}_3', x)

  x = keras.layers.Flatten(name='Flatten')(x)

  dense_n = 64
  x = keras.layers.Dense(dense_n, name='Dense_1')(x)
  x = layer_with_activation(f'{activation}_dense_1', x)
  x = keras.layers.Dense(dense_n, name='Dense_2')(x)
  x = layer_with_activation(f'{activation}_dense_2', x)
  x = keras.layers.Dense(dense_n, name='Dense_3')(x)
  x = layer_with_activation(f'{activation}_dense_3', x)
  outputs = keras.layers.Dense(NUM_TEMP_CLASSES, name='Output', activation="softmax")(x)

  model = keras.Model(inputs=inputs, outputs=outputs)
  
  model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=8e-4),
        loss='categorical_crossentropy',
        metrics=['accuracy'])
  return model

r_model = get_regressor_model()
cbk = [
       keras.callbacks.ModelCheckpoint(
           'r.hdf5', save_best_only=True, monitor='val_accuracy', mode='max'
           )]

train_conf, test_conf, train_one_hot_temp, test_one_hot_temp = train_test_split(conf, one_hot_temp, test_size=0.1)
r_model.fit(train_conf, train_one_hot_temp, epochs=30, validation_split=0.1, callbacks=cbk)
# Out:
# Epoch 1/30
# 254/254 [==============================] - 9s 34ms/step - loss: 1.3398 - accuracy: 0.4226 - val_loss: 1.2627 - val_accuracy: 0.4189
# Epoch 2/30
# 254/254 [==============================] - 9s 34ms/step - loss: 1.0473 - accuracy: 0.5185 - val_loss: 1.0550 - val_accuracy: 0.4689
# Epoch 3/30
# 254/254 [==============================] - 9s 34ms/step - loss: 0.9761 - accuracy: 0.5422 - val_loss: 1.0159 - val_accuracy: 0.5222
# Epoch 4/30
# 254/254 [==============================] - 9s 34ms/step - loss: 0.9517 - accuracy: 0.5556 - val_loss: 0.9783 - val_accuracy: 0.5522
# Epoch 5/30
# 254/254 [==============================] - 9s 34ms/step - loss: 0.9679 - accuracy: 0.5521 - val_loss: 0.9551 - val_accuracy: 0.5522
# Epoch 6/30
# 254/254 [==============================] - 9s 34ms/step - loss: 0.9201 - accuracy: 0.5714 - val_loss: 0.9276 - val_accuracy: 0.5467
# Epoch 7/30
# 254/254 [==============================] - 9s 33ms/step - loss: 0.9053 - accuracy: 0.5748 - val_loss: 0.9052 - val_accuracy: 0.5911
# Epoch 8/30
# 254/254 [==============================] - 9s 34ms/step - loss: 0.9105 - accuracy: 0.5789 - val_loss: 0.9185 - val_accuracy: 0.5844
# Epoch 9/30
# 254/254 [==============================] - 8s 33ms/step - loss: 0.9040 - accuracy: 0.5744 - val_loss: 0.9385 - val_accuracy: 0.5911
# Epoch 10/30
# 254/254 [==============================] - 9s 34ms/step - loss: 0.8805 - accuracy: 0.5916 - val_loss: 0.9374 - val_accuracy: 0.5411
# Epoch 11/30
# 254/254 [==============================] - 8s 33ms/step - loss: 0.8781 - accuracy: 0.5921 - val_loss: 0.8704 - val_accuracy: 0.6089
# Epoch 12/30
# 254/254 [==============================] - 8s 33ms/step - loss: 0.8793 - accuracy: 0.5969 - val_loss: 0.8991 - val_accuracy: 0.6033
# Epoch 13/30
# 254/254 [==============================] - 8s 33ms/step - loss: 0.8540 - accuracy: 0.5936 - val_loss: 0.8646 - val_accuracy: 0.6000
# Epoch 14/30
# 254/254 [==============================] - 8s 33ms/step - loss: 0.8607 - accuracy: 0.5956 - val_loss: 0.9400 - val_accuracy: 0.5744
# Epoch 15/30
# 254/254 [==============================] - 8s 33ms/step - loss: 0.8537 - accuracy: 0.6059 - val_loss: 0.9167 - val_accuracy: 0.5933
# Epoch 16/30
# 254/254 [==============================] - 8s 33ms/step - loss: 0.8548 - accuracy: 0.6012 - val_loss: 0.8720 - val_accuracy: 0.6022
# Epoch 17/30
# 254/254 [==============================] - 8s 33ms/step - loss: 0.8407 - accuracy: 0.6121 - val_loss: 0.8592 - val_accuracy: 0.6178
# Epoch 18/30
# 254/254 [==============================] - 8s 33ms/step - loss: 0.8438 - accuracy: 0.6068 - val_loss: 0.8580 - val_accuracy: 0.6011
# Epoch 19/30
# 254/254 [==============================] - 8s 33ms/step - loss: 0.8275 - accuracy: 0.6157 - val_loss: 0.8563 - val_accuracy: 0.6244
# Epoch 20/30
# 254/254 [==============================] - 8s 33ms/step - loss: 0.8294 - accuracy: 0.6152 - val_loss: 0.8615 - val_accuracy: 0.6078
# Epoch 21/30
# 254/254 [==============================] - 9s 34ms/step - loss: 0.8398 - accuracy: 0.6135 - val_loss: 0.9183 - val_accuracy: 0.5844
# Epoch 22/30
# 254/254 [==============================] - 9s 34ms/step - loss: 0.8287 - accuracy: 0.6109 - val_loss: 0.8523 - val_accuracy: 0.6256
# Epoch 23/30
# 254/254 [==============================] - 8s 33ms/step - loss: 0.8179 - accuracy: 0.6246 - val_loss: 0.8706 - val_accuracy: 0.6133
# Epoch 24/30
# 254/254 [==============================] - 8s 33ms/step - loss: 0.8201 - accuracy: 0.6225 - val_loss: 0.9448 - val_accuracy: 0.5500
# Epoch 25/30
# 254/254 [==============================] - 8s 33ms/step - loss: 0.8111 - accuracy: 0.6189 - val_loss: 0.8859 - val_accuracy: 0.6078
# Epoch 26/30
# 254/254 [==============================] - 8s 33ms/step - loss: 0.8130 - accuracy: 0.6241 - val_loss: 0.9016 - val_accuracy: 0.5767
# Epoch 27/30
# 254/254 [==============================] - 8s 33ms/step - loss: 0.8093 - accuracy: 0.6222 - val_loss: 0.8928 - val_accuracy: 0.6044
# Epoch 28/30
# 254/254 [==============================] - 8s 33ms/step - loss: 0.8011 - accuracy: 0.6319 - val_loss: 0.8643 - val_accuracy: 0.6156
# Epoch 29/30
# 254/254 [==============================] - 8s 33ms/step - loss: 0.8061 - accuracy: 0.6322 - val_loss: 0.8959 - val_accuracy: 0.5900
# Epoch 30/30
# 254/254 [==============================] - 9s 34ms/step - loss: 0.7907 - accuracy: 0.6332 - val_loss: 0.9162 - val_accuracy: 0.6100

# %%
r_model = keras.models.load_model("r.hdf5")
r_model.evaluate(test_conf, test_one_hot_temp)
# Out:
# 32/32 [==============================] - 0s 10ms/step - loss: 0.8645 - accuracy: 0.6150
# [0.8645309209823608, 0.6150000095367432]

# %%
# Modello DCGAN: implementiamo un keras.Model custom
class DCGAN(keras.Model):
    def __init__(self, discriminator, generator, latent_dim):
        super().__init__()
        self.discriminator = discriminator
        self.generator = generator
        self.latent_dim = latent_dim

    # funzione per la compilazione
    def compile(self, d_optimizer, g_optimizer, loss_fn):
        super().compile()
        self.d_optimizer = d_optimizer
        self.g_optimizer = g_optimizer
        self.loss_fn = loss_fn

    def train_step(self, train_batch):
        if isinstance(train_batch, tuple): #verifica che l'input isa una python tuple (numpy tensor)
            real_images, real_classes = train_batch

        # 1) campiona un batch di punti random nello spazio latente: z
        batch_size = tf.shape(real_images)[0]
        rand_classes = tf.one_hot(
            tf.random.uniform(
                shape=(batch_size,), 
                maxval=NUM_TEMP_CLASSES, 
                dtype=tf.int32
            ),
            NUM_TEMP_CLASSES,
        )
        rand_latent = tf.random.normal(shape=(batch_size, self.latent_dim))

        # 2) usa il generatore per creare dai vettori latenti immagini fake: immagine = G(z)
        generated_images = self.generator([rand_classes, rand_latent])

        # 3) determina la temperatura delle immagini generate grazie alla rete ausiliaria

        # 4) combina le immagini fake con quelle reali 
        combined_images = tf.concat([
                                     real_images, real_images, generated_images,
        ], axis=0)

        combined_classes = tf.concat([
                                   real_classes, rand_classes, rand_classes, 
        ], axis=0)

        # 5) assegna le label corrette (fae vs reale)
        labels = tf.concat([
            tf.ones((batch_size, 1)),  #immagini reali, temperature reali
            tf.zeros((batch_size, 1)), #immagini reali, temperature no
            tf.zeros((batch_size, 1)), #immagini generate, temperature corrispondenti
        ], axis=0)
        
        # 6) Trucco per diminuire la probabilità di collasso della rete (si aggiunge un po' di rumore random alle label) 
        labels += 0.05 * tf.random.uniform(tf.shape(labels))

        # 7) Training del discriminatore D
        with tf.GradientTape() as tape: #autograd
            predictions = self.discriminator(
                [combined_images, combined_classes]) #predizione = D(immagini)
            d_loss = self.loss_fn(labels, predictions) #calcolo loss
        grads = tape.gradient(d_loss, self.discriminator.trainable_weights) #backprop
        self.d_optimizer.apply_gradients(
            zip(grads, self.discriminator.trainable_weights) #aggiornamento pesi
        )

        # 8) crea un vettore di label corrispondenti a tutte immagii reali
        misleading_labels = tf.ones((batch_size, 1))

        # 9) Training del generatore (non si devono aggiornare ovviamente i pesi del discriminatore)
        with tf.GradientTape() as tape:
            generated_images = self.generator([rand_classes, rand_latent])
            predictions = self.discriminator([generated_images, rand_classes]) #predizione = D(G(z))
            g_loss = self.loss_fn(misleading_labels, predictions) #calcolo loss
        grads = tape.gradient(g_loss, self.generator.trainable_weights) #backprop
        self.g_optimizer.apply_gradients(zip(grads, self.generator.trainable_weights)) #aggiornamento pesi

        return {"d_loss": d_loss, "g_loss": g_loss}

# custom callback to save generated images peridoically during training
class GANMonitor(keras.callbacks.Callback):
    def __init__(self, num_img=11, latent_dim=128, norma=1.0):
        self.num_img = num_img
        self.latent_dim = latent_dim
        self.norma = norma

    def on_epoch_end(self, epoch, logs=None):
        classes = tf.one_hot(range(self.num_img), NUM_TEMP_CLASSES)
        latent = tf.random.normal(shape=(self.num_img, self.latent_dim))
        generated_images = self.model.generator([classes, latent])
        generated_images = generated_images * self.norma
        fig, axs = plt.subplots(1, self.num_img, figsize=(18, 5))
        for i in range(self.num_img):
            img = generated_images[i].numpy().reshape(28, 28)
            axs[i].imshow(img)
        fig.savefig(f"{epoch}.png")
        plt.close()

# %%
# Training della GAN

# Ottimizzatori di G e D
# learning_rate=0.0002, beta_1=0.5 are recommened
generator_optimizer = keras.optimizers.Adam(
    learning_rate=0.0002, beta_1=0.5, beta_2=0.9)

discriminator_optimizer = keras.optimizers.Adam(
    learning_rate=0.0002, beta_1=0.5, beta_2=0.9)
# Loss function
gan_loss = keras.losses.BinaryCrossentropy(from_logits=True)

# Epochs
EPOCHS = 300

# Callbacks
cbk = GANMonitor(num_img=NUM_TEMP_CLASSES, latent_dim=LATENT_DIM, norma=255)

# Istanziamento modello
gan = DCGAN(discriminator=d_model, generator=g_model, latent_dim=LATENT_DIM)

# Compilazione
gan.compile(d_optimizer=discriminator_optimizer,
    g_optimizer=generator_optimizer,
    loss_fn=gan_loss,
)

# %%
gan.fit(dataset, epochs=EPOCHS, callbacks=[cbk], batch_size=64)
# Out:
# Epoch 1/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6528 - g_loss: 0.6783
# Epoch 2/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6523 - g_loss: 0.6759
# Epoch 3/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6504 - g_loss: 0.6760
# Epoch 4/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6499 - g_loss: 0.6764
# Epoch 5/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6494 - g_loss: 0.6753
# Epoch 6/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6494 - g_loss: 0.6751
# Epoch 7/300
# 157/157 [==============================] - 6s 41ms/step - d_loss: 0.6488 - g_loss: 0.6732
# Epoch 8/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6488 - g_loss: 0.6725
# Epoch 9/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6481 - g_loss: 0.6742
# Epoch 10/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6499 - g_loss: 0.6752
# Epoch 11/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6465 - g_loss: 0.6736
# Epoch 12/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6489 - g_loss: 0.6749
# Epoch 13/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6494 - g_loss: 0.6721
# Epoch 14/300
# 157/157 [==============================] - 3s 21ms/step - d_loss: 0.6483 - g_loss: 0.6740
# Epoch 15/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6460 - g_loss: 0.6767
# Epoch 16/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6464 - g_loss: 0.6754
# Epoch 17/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6450 - g_loss: 0.6733
# Epoch 18/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6455 - g_loss: 0.6736
# Epoch 19/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6440 - g_loss: 0.6760
# Epoch 20/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6467 - g_loss: 0.6727
# Epoch 21/300
# 157/157 [==============================] - 3s 22ms/step - d_loss: 0.6442 - g_loss: 0.6746
# Epoch 22/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6457 - g_loss: 0.6760
# Epoch 23/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6461 - g_loss: 0.6730
# Epoch 24/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6469 - g_loss: 0.6743
# Epoch 25/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6450 - g_loss: 0.6745
# Epoch 26/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6430 - g_loss: 0.6756
# Epoch 27/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6437 - g_loss: 0.6751
# Epoch 28/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6429 - g_loss: 0.6735
# Epoch 29/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6413 - g_loss: 0.6770
# Epoch 30/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6422 - g_loss: 0.6776
# Epoch 31/300
# 157/157 [==============================] - 3s 22ms/step - d_loss: 0.6423 - g_loss: 0.6772
# Epoch 32/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6430 - g_loss: 0.6760
# Epoch 33/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6442 - g_loss: 0.6765
# Epoch 34/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6424 - g_loss: 0.6757
# Epoch 35/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6417 - g_loss: 0.6746
# Epoch 36/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6433 - g_loss: 0.6764
# Epoch 37/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6420 - g_loss: 0.6762
# Epoch 38/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6436 - g_loss: 0.6776
# Epoch 39/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6427 - g_loss: 0.6755
# Epoch 40/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6437 - g_loss: 0.6752
# Epoch 41/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6430 - g_loss: 0.6748
# Epoch 42/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6428 - g_loss: 0.6744
# Epoch 43/300
# 157/157 [==============================] - 4s 23ms/step - d_loss: 0.6436 - g_loss: 0.6735
# Epoch 44/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6434 - g_loss: 0.6750
# Epoch 45/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6419 - g_loss: 0.6752
# Epoch 46/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6440 - g_loss: 0.6759
# Epoch 47/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6418 - g_loss: 0.6748
# Epoch 48/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6433 - g_loss: 0.6754
# Epoch 49/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6428 - g_loss: 0.6731
# Epoch 50/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6421 - g_loss: 0.6743
# Epoch 51/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6406 - g_loss: 0.6744
# Epoch 52/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6424 - g_loss: 0.6743
# Epoch 53/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6412 - g_loss: 0.6768
# Epoch 54/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6430 - g_loss: 0.6727
# Epoch 55/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6403 - g_loss: 0.6758
# Epoch 56/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6406 - g_loss: 0.6744
# Epoch 57/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6423 - g_loss: 0.6724
# Epoch 58/300
# 157/157 [==============================] - 4s 24ms/step - d_loss: 0.6408 - g_loss: 0.6747
# Epoch 59/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6410 - g_loss: 0.6755
# Epoch 60/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6420 - g_loss: 0.6748
# Epoch 61/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6405 - g_loss: 0.6746
# Epoch 62/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6414 - g_loss: 0.6741
# Epoch 63/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6413 - g_loss: 0.6765
# Epoch 64/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6409 - g_loss: 0.6753
# Epoch 65/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6396 - g_loss: 0.6766
# Epoch 66/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6383 - g_loss: 0.6770
# Epoch 67/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6397 - g_loss: 0.6762
# Epoch 68/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6410 - g_loss: 0.6746
# Epoch 69/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6395 - g_loss: 0.6769
# Epoch 70/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6404 - g_loss: 0.6749
# Epoch 71/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6416 - g_loss: 0.6749
# Epoch 72/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6404 - g_loss: 0.6747
# Epoch 73/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6391 - g_loss: 0.6774
# Epoch 74/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6379 - g_loss: 0.6779
# Epoch 75/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6393 - g_loss: 0.6769
# Epoch 76/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6371 - g_loss: 0.6758
# Epoch 77/300
# 157/157 [==============================] - 4s 25ms/step - d_loss: 0.6403 - g_loss: 0.6736
# Epoch 78/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6385 - g_loss: 0.6753
# Epoch 79/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6389 - g_loss: 0.6755
# Epoch 80/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6392 - g_loss: 0.6755
# Epoch 81/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6418 - g_loss: 0.6778
# Epoch 82/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6378 - g_loss: 0.6795
# Epoch 83/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6410 - g_loss: 0.6744
# Epoch 84/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6407 - g_loss: 0.6762
# Epoch 85/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6409 - g_loss: 0.6763
# Epoch 86/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6383 - g_loss: 0.6761
# Epoch 87/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6398 - g_loss: 0.6777
# Epoch 88/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6392 - g_loss: 0.6766
# Epoch 89/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6398 - g_loss: 0.6761
# Epoch 90/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6387 - g_loss: 0.6758
# Epoch 91/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6374 - g_loss: 0.6769
# Epoch 92/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6383 - g_loss: 0.6787
# Epoch 93/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6370 - g_loss: 0.6784
# Epoch 94/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6382 - g_loss: 0.6788
# Epoch 95/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6367 - g_loss: 0.6761
# Epoch 96/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6393 - g_loss: 0.6748
# Epoch 97/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6380 - g_loss: 0.6776
# Epoch 98/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6388 - g_loss: 0.6756
# Epoch 99/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6390 - g_loss: 0.6722
# Epoch 100/300
# 157/157 [==============================] - 4s 26ms/step - d_loss: 0.6383 - g_loss: 0.6746
# Epoch 101/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6367 - g_loss: 0.6762
# Epoch 102/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6394 - g_loss: 0.6762
# Epoch 103/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6393 - g_loss: 0.6761
# Epoch 104/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6374 - g_loss: 0.6754
# Epoch 105/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6381 - g_loss: 0.6745
# Epoch 106/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6390 - g_loss: 0.6776
# Epoch 107/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6361 - g_loss: 0.6784
# Epoch 108/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6358 - g_loss: 0.6814
# Epoch 109/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6370 - g_loss: 0.6799
# Epoch 110/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6359 - g_loss: 0.6788
# Epoch 111/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6365 - g_loss: 0.6780
# Epoch 112/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6336 - g_loss: 0.6780
# Epoch 113/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6368 - g_loss: 0.6788
# Epoch 114/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6372 - g_loss: 0.6767
# Epoch 115/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6369 - g_loss: 0.6742
# Epoch 116/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6392 - g_loss: 0.6761
# Epoch 117/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6360 - g_loss: 0.6765
# Epoch 118/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6346 - g_loss: 0.6753
# Epoch 119/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6353 - g_loss: 0.6783
# Epoch 120/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6367 - g_loss: 0.6771
# Epoch 121/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6364 - g_loss: 0.6762
# Epoch 122/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6375 - g_loss: 0.6778
# Epoch 123/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6389 - g_loss: 0.6756
# Epoch 124/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6349 - g_loss: 0.6762
# Epoch 125/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6359 - g_loss: 0.6768
# Epoch 126/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6374 - g_loss: 0.6781
# Epoch 127/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6375 - g_loss: 0.6777
# Epoch 128/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6364 - g_loss: 0.6768
# Epoch 129/300
# 157/157 [==============================] - 4s 28ms/step - d_loss: 0.6356 - g_loss: 0.6774
# Epoch 130/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6358 - g_loss: 0.6779
# Epoch 131/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6377 - g_loss: 0.6773
# Epoch 132/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6351 - g_loss: 0.6751
# Epoch 133/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6346 - g_loss: 0.6759
# Epoch 134/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6351 - g_loss: 0.6760
# Epoch 135/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6345 - g_loss: 0.6761
# Epoch 136/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6364 - g_loss: 0.6761
# Epoch 137/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6375 - g_loss: 0.6724
# Epoch 138/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6365 - g_loss: 0.6722
# Epoch 139/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6361 - g_loss: 0.6753
# Epoch 140/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6357 - g_loss: 0.6760
# Epoch 141/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6355 - g_loss: 0.6745
# Epoch 142/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6355 - g_loss: 0.6744
# Epoch 143/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6366 - g_loss: 0.6739
# Epoch 144/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6368 - g_loss: 0.6759
# Epoch 145/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6359 - g_loss: 0.6743
# Epoch 146/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6352 - g_loss: 0.6719
# Epoch 147/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6365 - g_loss: 0.6756
# Epoch 148/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6339 - g_loss: 0.6743
# Epoch 149/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6349 - g_loss: 0.6760
# Epoch 150/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6356 - g_loss: 0.6778
# Epoch 151/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6353 - g_loss: 0.6786
# Epoch 152/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6349 - g_loss: 0.6785
# Epoch 153/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6360 - g_loss: 0.6775
# Epoch 154/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6341 - g_loss: 0.6770
# Epoch 155/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6347 - g_loss: 0.6763
# Epoch 156/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6348 - g_loss: 0.6766
# Epoch 157/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6352 - g_loss: 0.6789
# Epoch 158/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6337 - g_loss: 0.6760
# Epoch 159/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6348 - g_loss: 0.6782
# Epoch 160/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6367 - g_loss: 0.6743
# Epoch 161/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6349 - g_loss: 0.6761
# Epoch 162/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6346 - g_loss: 0.6754
# Epoch 163/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6363 - g_loss: 0.6756
# Epoch 164/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6334 - g_loss: 0.6741
# Epoch 165/300
# 157/157 [==============================] - 5s 30ms/step - d_loss: 0.6347 - g_loss: 0.6782
# Epoch 166/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6351 - g_loss: 0.6776
# Epoch 167/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6358 - g_loss: 0.6765
# Epoch 168/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6348 - g_loss: 0.6792
# Epoch 169/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6339 - g_loss: 0.6777
# Epoch 170/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6344 - g_loss: 0.6774
# Epoch 171/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6347 - g_loss: 0.6788
# Epoch 172/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6330 - g_loss: 0.6772
# Epoch 173/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6316 - g_loss: 0.6771
# Epoch 174/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6335 - g_loss: 0.6779
# Epoch 175/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6349 - g_loss: 0.6761
# Epoch 176/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6322 - g_loss: 0.6762
# Epoch 177/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6335 - g_loss: 0.6792
# Epoch 178/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6331 - g_loss: 0.6795
# Epoch 179/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6342 - g_loss: 0.6776
# Epoch 180/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6333 - g_loss: 0.6795
# Epoch 181/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6349 - g_loss: 0.6761
# Epoch 182/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6339 - g_loss: 0.6759
# Epoch 183/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6347 - g_loss: 0.6778
# Epoch 184/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6338 - g_loss: 0.6769
# Epoch 185/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6342 - g_loss: 0.6754
# Epoch 186/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6324 - g_loss: 0.6773
# Epoch 187/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6321 - g_loss: 0.6765
# Epoch 188/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6336 - g_loss: 0.6774
# Epoch 189/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6340 - g_loss: 0.6771
# Epoch 190/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6354 - g_loss: 0.6739
# Epoch 191/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6329 - g_loss: 0.6746
# Epoch 192/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6339 - g_loss: 0.6752
# Epoch 193/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6348 - g_loss: 0.6786
# Epoch 194/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6332 - g_loss: 0.6787
# Epoch 195/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6345 - g_loss: 0.6785
# Epoch 196/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6334 - g_loss: 0.6780
# Epoch 197/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6330 - g_loss: 0.6741
# Epoch 198/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6336 - g_loss: 0.6768
# Epoch 199/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6338 - g_loss: 0.6749
# Epoch 200/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6327 - g_loss: 0.6726
# Epoch 201/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6335 - g_loss: 0.6749
# Epoch 202/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6327 - g_loss: 0.6790
# Epoch 203/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6342 - g_loss: 0.6767
# Epoch 204/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6331 - g_loss: 0.6785
# Epoch 205/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6321 - g_loss: 0.6768
# Epoch 206/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6301 - g_loss: 0.6764
# Epoch 207/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6316 - g_loss: 0.6763
# Epoch 208/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6319 - g_loss: 0.6795
# Epoch 209/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6316 - g_loss: 0.6792
# Epoch 210/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6327 - g_loss: 0.6757
# Epoch 211/300
# 157/157 [==============================] - 5s 35ms/step - d_loss: 0.6327 - g_loss: 0.6777
# Epoch 212/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6321 - g_loss: 0.6754
# Epoch 213/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6308 - g_loss: 0.6773
# Epoch 214/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6304 - g_loss: 0.6787
# Epoch 215/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6317 - g_loss: 0.6786
# Epoch 216/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6324 - g_loss: 0.6750
# Epoch 217/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6318 - g_loss: 0.6796
# Epoch 218/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6315 - g_loss: 0.6770
# Epoch 219/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6315 - g_loss: 0.6773
# Epoch 220/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6315 - g_loss: 0.6772
# Epoch 221/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6330 - g_loss: 0.6780
# Epoch 222/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6316 - g_loss: 0.6751
# Epoch 223/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6304 - g_loss: 0.6766
# Epoch 224/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6289 - g_loss: 0.6798
# Epoch 225/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6304 - g_loss: 0.6763
# Epoch 226/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6308 - g_loss: 0.6799
# Epoch 227/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6325 - g_loss: 0.6809
# Epoch 228/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6301 - g_loss: 0.6808
# Epoch 229/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6309 - g_loss: 0.6786
# Epoch 230/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6306 - g_loss: 0.6762
# Epoch 231/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6297 - g_loss: 0.6782
# Epoch 232/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6303 - g_loss: 0.6804
# Epoch 233/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6284 - g_loss: 0.6788
# Epoch 234/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6312 - g_loss: 0.6802
# Epoch 235/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6309 - g_loss: 0.6800
# Epoch 236/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6305 - g_loss: 0.6803
# Epoch 237/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6304 - g_loss: 0.6785
# Epoch 238/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6306 - g_loss: 0.6776
# Epoch 239/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6291 - g_loss: 0.6773
# Epoch 240/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6298 - g_loss: 0.6776
# Epoch 241/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6287 - g_loss: 0.6784
# Epoch 242/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6296 - g_loss: 0.6764
# Epoch 243/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6301 - g_loss: 0.6769
# Epoch 244/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6277 - g_loss: 0.6796
# Epoch 245/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6305 - g_loss: 0.6805
# Epoch 246/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6298 - g_loss: 0.6793
# Epoch 247/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6306 - g_loss: 0.6790
# Epoch 248/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6303 - g_loss: 0.6802
# Epoch 249/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6295 - g_loss: 0.6819
# Epoch 250/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6290 - g_loss: 0.6805
# Epoch 251/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6308 - g_loss: 0.6794
# Epoch 252/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6299 - g_loss: 0.6775
# Epoch 253/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6303 - g_loss: 0.6794
# Epoch 254/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6303 - g_loss: 0.6795
# Epoch 255/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6290 - g_loss: 0.6799
# Epoch 256/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6292 - g_loss: 0.6795
# Epoch 257/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6275 - g_loss: 0.6793
# Epoch 258/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6280 - g_loss: 0.6824
# Epoch 259/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6272 - g_loss: 0.6804
# Epoch 260/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6308 - g_loss: 0.6806
# Epoch 261/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6308 - g_loss: 0.6795
# Epoch 262/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6290 - g_loss: 0.6804
# Epoch 263/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6285 - g_loss: 0.6782
# Epoch 264/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6299 - g_loss: 0.6796
# Epoch 265/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6293 - g_loss: 0.6752
# Epoch 266/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6291 - g_loss: 0.6792
# Epoch 267/300
# 157/157 [==============================] - 6s 37ms/step - d_loss: 0.6280 - g_loss: 0.6809
# Epoch 268/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6297 - g_loss: 0.6789
# Epoch 269/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6293 - g_loss: 0.6778
# Epoch 270/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6290 - g_loss: 0.6789
# Epoch 271/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6298 - g_loss: 0.6788
# Epoch 272/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6287 - g_loss: 0.6779
# Epoch 273/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6287 - g_loss: 0.6792
# Epoch 274/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6281 - g_loss: 0.6812
# Epoch 275/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6287 - g_loss: 0.6802
# Epoch 276/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6276 - g_loss: 0.6805
# Epoch 277/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6294 - g_loss: 0.6793
# Epoch 278/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6294 - g_loss: 0.6776
# Epoch 279/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6285 - g_loss: 0.6790
# Epoch 280/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6292 - g_loss: 0.6791
# Epoch 281/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6280 - g_loss: 0.6805
# Epoch 282/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6287 - g_loss: 0.6818
# Epoch 283/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6285 - g_loss: 0.6812
# Epoch 284/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6274 - g_loss: 0.6802
# Epoch 285/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6285 - g_loss: 0.6800
# Epoch 286/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6278 - g_loss: 0.6799
# Epoch 287/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6285 - g_loss: 0.6801
# Epoch 288/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6280 - g_loss: 0.6778
# Epoch 289/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6286 - g_loss: 0.6800
# Epoch 290/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6285 - g_loss: 0.6770
# Epoch 291/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6298 - g_loss: 0.6765
# Epoch 292/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6284 - g_loss: 0.6806
# Epoch 293/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6300 - g_loss: 0.6784
# Epoch 294/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6285 - g_loss: 0.6805
# Epoch 295/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6285 - g_loss: 0.6791
# Epoch 296/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6270 - g_loss: 0.6777
# Epoch 297/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6284 - g_loss: 0.6785
# Epoch 298/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6284 - g_loss: 0.6795
# Epoch 299/300
# 157/157 [==============================] - 3s 20ms/step - d_loss: 0.6278 - g_loss: 0.6788
# Epoch 300/300
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.6278 - g_loss: 0.6784

# %%
classes = tf.one_hot(range(NUM_TEMP_CLASSES), NUM_TEMP_CLASSES)
latent = tf.random.normal(shape=(NUM_TEMP_CLASSES, LATENT_DIM))
generated_images = gan.generator([classes, latent])
generated_images = generated_images
fig, axs = plt.subplots(1, NUM_TEMP_CLASSES, figsize=(17, 5))
for i in range(NUM_TEMP_CLASSES):
    img = generated_images[i].numpy().reshape(28, 28)
    axs[i].imshow(img)

# %% [markdown]
# Si vede come la progressione con la temperatura, almeno graficamente, è simile a quella attesa.
