# %% [markdown]
# <a href="https://colab.research.google.com/github/raeubaen/ml/blob/master/Conditional%20GAN-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import models & layers from TF/keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# tensor manipulation library
import numpy as np
# plotting library
import matplotlib.pyplot as plt
# !pip install plot_model
from plot_model import plot_model
# disabling eager (slower) execution
#from tensorflow.python.framework.ops import disable_eager_execution
#disable_eager_execution()
from sklearn.model_selection import train_test_split
# Out:
# Requirement already satisfied: plot_model in /usr/local/lib/python3.6/dist-packages (0.20)

# %%
# dataset download
# !wget http://www.roma1.infn.it/~giagu/datasets/ising2_conf.dat
# !wget http://www.roma1.infn.it/~giagu/datasets/ising2_label.dat

# reading configurations and temperatures into numpy 
# (10k elements with 28x28 spin configuration)
conf, temp = np.loadtxt('ising2_conf.dat'), np.loadtxt('ising2_label.dat')
# Out:
# --2020-06-04 13:30:35--  http://www.roma1.infn.it/~giagu/datasets/ising2_conf.dat
# Resolving www.roma1.infn.it (www.roma1.infn.it)... 141.108.26.150, 141.108.26.1
# Connecting to www.roma1.infn.it (www.roma1.infn.it)|141.108.26.150|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19060775 (18M)
# Saving to: ‘ising2_conf.dat.4’
#
# ising2_conf.dat.4   100%[===================>]  18.18M  2.47MB/s    in 5.6s
#
# 2020-06-04 13:30:42 (3.23 MB/s) - ‘ising2_conf.dat.4’ saved [19060775/19060775]
#
# --2020-06-04 13:30:43--  http://www.roma1.infn.it/~giagu/datasets/ising2_label.dat
# Resolving www.roma1.infn.it (www.roma1.infn.it)... 141.108.26.150, 141.108.26.1
# Connecting to www.roma1.infn.it (www.roma1.infn.it)|141.108.26.150|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 81025 (79K)
# Saving to: ‘ising2_label.dat.4’
#
# ising2_label.dat.4  100%[===================>]  79.13K   243KB/s    in 0.3s
#
# 2020-06-04 13:30:44 (243 KB/s) - ‘ising2_label.dat.4’ saved [81025/81025]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-219-81b2d4d0e4fc> in <module>()
#       5 # reading configurations and temperatures into numpy
#       6 # (10k elements with 28x28 spin configuration)
# ----> 7 conf, temp = np.loadtxt('ising2_conf.dat'), np.loadtxt('ising2_label.dat')
#
# /usr/local/lib/python3.6/dist-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#    1157         # converting the data
#    1158         X = None
# -> 1159         for x in read_data(_loadtxt_chunksize):
#    1160             if X is None:
#    1161                 X = np.array(x, dtype)
#
# /usr/local/lib/python3.6/dist-packages/numpy/lib/npyio.py in read_data(chunk_size)
#    1088
#    1089             # Then pack it according to the dtype's nesting
# -> 1090             items = pack_items(items, packing)
#    1091             X.append(items)
#    1092             if len(X) > chunk_size:
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/_internal.py in __call__(self, *args, **kwargs)
#     874         self.func = func
#     875     def __call__(self, *args, **kwargs):
# --> 876         return self.func(self, *args, **kwargs)
#     877
#
# /usr/local/lib/python3.6/dist-packages/numpy/lib/npyio.py in pack_items(self, items, packing)
#    1042             ret = []
#    1043             for length, subpacking in packing:
# -> 1044                 ret.append(self(items[start:start+length], subpacking))
#    1045                 start += length
#    1046             return tuple(ret)
#
# KeyboardInterrupt:

# %%
BATCH_SIZE = 64
IMG_SHAPE = (28, 28, 1)
NUM_TEMP_CLASSES = 10
EMBEDDING_DIM = 64
LATENT_DIM = 128

# %%
# reshaping configurations into matrix form and specifying dtype
conf = conf.reshape(-1, *IMG_SHAPE).astype('float32')
label = (temp.reshape(-1, 1)*2).astype("int32")

one_hot_temp = keras.utils.to_categorical(label)
# converting data (conf and temperatures) into tensorflow Dataset
dataset = tf.data.Dataset.from_tensor_slices((conf, one_hot_temp))
# shuffling and prefetching
dataset = dataset.shuffle(buffer_size=1024).batch(BATCH_SIZE).prefetch(32)

# %%
def get_discriminator_model():

    temp_input = layers.Input(shape=(NUM_TEMP_CLASSES,), name="D_Temp_Input")

    t = layers.Dense(28*28, name="D_temp_Dense")(temp_input)
    t = layers.LeakyReLU(name="D_temp_LReLU")(t)
    t = layers.Reshape(IMG_SHAPE, name="D_temp_Reshape")(t)

    img_input = layers.Input(shape=IMG_SHAPE, name="D_Image_Input")
    x = layers.Concatenate(name="D_Concatenate")([t, img_input])

    x = layers.Conv2D(64, (5, 5), strides=(2, 2), padding='same', 
                      input_shape=IMG_SHAPE, name="D_Conv2D_1")(x)
    x = layers.LeakyReLU(name="D_LReLu_1")(x)
    x = layers.Dropout(0.3, name="D_DropOut_1")(x)

    x = layers.Conv2D(128, (5, 5), strides=(2, 2), 
                      padding='same', name="D_Conv2D_2")(x)
    x = layers.LeakyReLU(name="D_LReLu_2")(x)
    x = layers.Dropout(0.3, name="D_DropOut_2")(x)

    x = layers.Flatten(name="D_Final_Flatten")(x)
    x = layers.Dense(1, name="D_Final_Dense", activation="sigmoid")(x)

    model = keras.models.Model([img_input, temp_input], x, name="discriminator")
    return model

d_model = get_discriminator_model()
plot_model(d_model, 
  dpi=60, color=True, style=1, to_file="d_model.png", show_layer_names=True)

# %%
class RandomInvertLayer(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
      super().__init__(**kwargs)

    def call(self, inputs):
      samples = 2*tf.random.categorical(tf.math.log([[0.5, 0.5]]), tf.shape(inputs)[0])-1

      # Reshape b with dim_array and perform elementwise multiplication with 
      # broadcasting along the singleton dimensions for the final output
      samples = tf.reshape(samples, [-1,  1,  1,  1])
      return inputs * tf.cast(samples, "float32")

# %%
def get_generator_model():

    temp_input = layers.Input(shape=(NUM_TEMP_CLASSES,), name="G_Temp_Input")

    latent_vector = layers.Input(shape=(LATENT_DIM,), name="G_Latent_Input")

    x = layers.Concatenate(name="G_Concatenate")([latent_vector, temp_input])

    x = layers.Dense(7*7*256, use_bias=False, 
                     input_shape=(2*LATENT_DIM,), name="G_Dense_1")(x)
    x = layers.BatchNormalization(name="G_BM_1")(x)
    x = layers.LeakyReLU(name="G_LReLU_1")(x)

    x = layers.Reshape((7, 7, 256), name="G_Reshape")(x)
    
    x = layers.Conv2DTranspose(128, (4, 4), strides=(1, 1), padding='same', 
                               use_bias=False, name="G_Conv2DTranspose_1")(x)
    x = layers.BatchNormalization(name="G_BM_2")(x)
    x = layers.LeakyReLU(name="G_LReLU_2")(x)

    x = layers.Conv2DTranspose(64, (4, 4), strides=(2, 2), padding='same', 
                               use_bias=False, name="G_Conv2DTranspose_2")(x)
    x = layers.BatchNormalization(name="G_BM_3")(x)
    x = layers.LeakyReLU(name="G_LReLU_3")(x)

    x = layers.Conv2DTranspose(1, (7, 7), strides=(2, 2), padding='same',
       use_bias=False, activation=tf.tanh, name="G_Final_Conv2DTranspose")(x)

    x = RandomInvertLayer(name="G_random_invert")(x)
    model = keras.models.Model([temp_input, latent_vector], x, name="generator")
    return model

g_model = get_generator_model()
print(g_model.count_params())
plot_model(g_model, 
  dpi=60, color=True, style=1, to_file="g_model.png", show_layer_names=True)
# Out:
# 2440512

# %%
def get_regressor_model():
  #modello da https://github.com/raeubaen/ml/blob/master/NB_CNN_LC3_2020.ipynb
  inputs = keras.Input(shape=(28,28,1))

  data_augmentation = keras.Sequential([
    keras.layers.experimental.preprocessing.RandomFlip()
  ], name='DataAugm')

  activation = "relu"

  x = data_augmentation(inputs)

  layer_with_activation = lambda name, x: \
      keras.layers.ReLU(name=name)(x)

  ks = 2
  f1 = 64
  x = keras.layers.Conv2D(f1, kernel_size=(ks,ks), name='Conv_1')(x)
  x = layer_with_activation(f'{activation}_1', x)
  x = keras.layers.MaxPooling2D((2,2), name='MaxPool_1')(x)
  x = keras.layers.Conv2D(f1, kernel_size=(ks,ks), name='Conv_2')(x)
  x = layer_with_activation(f'{activation}_2', x)
  x = keras.layers.MaxPooling2D((2,2), name='MaxPool_2')(x)

  x = keras.layers.Conv2D(f1, kernel_size=(ks,ks), name='Conv_3')(x)
  x = layer_with_activation(f'{activation}_3', x)

  x = keras.layers.Flatten(name='Flatten')(x)

  dense_n = 64
  x = keras.layers.Dense(dense_n, name='Dense_1')(x)
  x = layer_with_activation(f'{activation}_dense_1', x)
  x = keras.layers.Dense(dense_n, name='Dense_2')(x)
  x = layer_with_activation(f'{activation}_dense_2', x)
  x = keras.layers.Dense(dense_n, name='Dense_3')(x)
  x = layer_with_activation(f'{activation}_dense_3', x)
  outputs = keras.layers.Dense(NUM_TEMP_CLASSES, name='Output', activation="softmax")(x)

  model = keras.Model(inputs=inputs, outputs=outputs)
  
  model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=8e-4),
        loss='categorical_crossentropy',
        metrics=['accuracy'])
  return model

r_model = get_regressor_model()
cbk = [
       keras.callbacks.ModelCheckpoint(
           'r.hdf5', save_best_only=True, monitor='val_accuracy', mode='max'
           )]

train_conf, test_conf, train_one_hot_temp, test_one_hot_temp = train_test_split(conf, one_hot_temp, test_size=0.1)
r_model.fit(train_conf, train_one_hot_temp, epochs=30, validation_split=0.1, callbacks=cbk)

# %%
r_model = keras.models.load_model("r.hdf5")
r_model.evaluate(test_conf, test_one_hot_temp)
# Out:
# 32/32 [==============================] - 0s 2ms/step - loss: 0.7973 - accuracy: 0.6250
# [0.7972729206085205, 0.625]

# %%
# Modello DCGAN: implementiamo un keras.Model custom
class DCGAN(keras.Model):
    def __init__(self, discriminator, generator, regressor, latent_dim, mode=None):
        super().__init__()
        self.discriminator = discriminator
        self.generator = generator
        self.regressor = regressor
        self.latent_dim = latent_dim
        self.mode = mode

    # funzione per la compilazione
    def compile(self, d_optimizer, g_optimizer, loss_fn):
        super().compile()
        self.d_optimizer = d_optimizer
        self.g_optimizer = g_optimizer
        self.loss_fn = loss_fn

    def train_step(self, train_batch):
        if isinstance(train_batch, tuple): #verifica che l'input isa una python tuple (numpy tensor)
            real_images, real_classes = train_batch

        # 1) campiona un batch di punti random nello spazio latente: z
        batch_size = tf.shape(real_images)[0]
        rand_classes = tf.one_hot(
            tf.random.uniform(
                shape=(batch_size,), 
                maxval=NUM_TEMP_CLASSES, 
                dtype=tf.int32
            ),
            NUM_TEMP_CLASSES,
        )
        rand_latent = tf.random.normal(shape=(batch_size, self.latent_dim))

        # 2) usa il generatore per creare dai vettori latenti immagini fake: immagine = G(z)
        generated_images = self.generator([rand_classes, rand_latent])
        
        # 3) determina la temperatura delle immagini generate grazie alla rete ausiliaria

        if self.mode == "A":
            # 4) combina le immagini fake con quelle reali 
            combined_images = tf.concat([
                                        real_images, generated_images,# real_images,
            ], axis=0)

            combined_classes = tf.concat([
                                      real_classes, rand_classes,# rand_classes,
            ], axis=0)

            # 5) assegna le label corrette (fae vs reale)
            labels = tf.concat([
                tf.ones((batch_size, 1)),  #immagini reali, temperature reali
                tf.zeros((batch_size, 1)), #immagini generate, temperature corrispondenti
                #tf.zeros((batch_size, 1)), #immagini reali, temperature no
            ], axis=0)

        if self.mode == "B":
            generated_classes = self.regressor(generated_images)

            # 4) combina le immagini fake con quelle reali 
            combined_images = tf.concat([
                                        real_images, generated_images, real_images,
            ], axis=0)

            combined_classes = tf.concat([
                                      real_classes, rand_classes, rand_classes,
            ], axis=0)

            # 5) assegna le label corrette (fae vs reale)
            labels = tf.concat([
                tf.ones((batch_size, 1)),  #immagini reali, temperature reali
                tf.zeros((batch_size, 1)), #immagini generate, temperature corrispondenti
                tf.zeros((batch_size, 1)), #immagini reali, temperature no
            ], axis=0)

        if self.mode == "C":
            generated_classes = self.regressor(generated_images)
            # 4) combina le immagini fake con quelle reali 
            combined_images = tf.concat([
                                        real_images, generated_images, real_images,
            ], axis=0)

            combined_classes = tf.concat([
                                      real_classes, generated_classes, rand_classes,
            ], axis=0)

            # 5) assegna le label corrette (fae vs reale)
            labels = tf.concat([
                tf.ones((batch_size, 1)),  #immagini reali, temperature reali
                tf.zeros((batch_size, 1)), #immagini generate, temperature corrispondenti
                tf.zeros((batch_size, 1)), #immagini reali, temperature no
            ], axis=0)

        # 6) Trucco per diminuire la probabilità di collasso della rete (si aggiunge un po' di rumore random alle label) 
        labels += 0.05 * tf.random.uniform(tf.shape(labels))

        # 7) Training del discriminatore D
        with tf.GradientTape() as tape: #autograd
            predictions = self.discriminator(
                [combined_images, combined_classes]) #predizione = D(immagini)
            d_loss = self.loss_fn(labels, predictions) #calcolo loss
        grads = tape.gradient(d_loss, self.discriminator.trainable_weights) #backprop
        self.d_optimizer.apply_gradients(
            zip(grads, self.discriminator.trainable_weights) #aggiornamento pesi
        )

        # 8) crea un vettore di label corrispondenti a tutte immagii reali
        misleading_labels = tf.ones((batch_size, 1))

        # 9) Training del generatore (non si devono aggiornare ovviamente i pesi del discriminatore)
        with tf.GradientTape() as tape:
            generated_images = self.generator([rand_classes, rand_latent])
            predictions = self.discriminator([generated_images, rand_classes]) #predizione = D(G(z))
            g_loss = self.loss_fn(misleading_labels, predictions) #calcolo loss
        grads = tape.gradient(g_loss, self.generator.trainable_weights) #backprop
        self.g_optimizer.apply_gradients(zip(grads, self.generator.trainable_weights)) #aggiornamento pesi

        return {"d_loss": d_loss, "g_loss": g_loss}

# custom callback to save generated images peridoically during training
class GANMonitor(keras.callbacks.Callback):
    def __init__(self, num_img=11, latent_dim=128, norma=1.0):
        self.num_img = num_img
        self.latent_dim = latent_dim
        self.norma = norma

    def on_epoch_end(self, epoch, logs=None):
        classes = tf.one_hot(range(self.num_img), NUM_TEMP_CLASSES)
        latent = tf.random.normal(shape=(self.num_img, self.latent_dim))
        generated_images = self.model.generator([classes, latent])
        generated_images = generated_images * self.norma
        fig, axs = plt.subplots(1, self.num_img, figsize=(18, 5))
        for i in range(self.num_img):
            img = generated_images[i].numpy().reshape(28, 28)
            axs[i].imshow(img)
        fig.savefig(f"{epoch}.png")
        plt.close()

# %%
# Training della GAN

# Ottimizzatori di G e D
# learning_rate=0.0002, beta_1=0.5 are recommened
generator_optimizer = keras.optimizers.Adam(
    learning_rate=0.0002, beta_1=0.5, beta_2=0.9)

discriminator_optimizer = keras.optimizers.Adam(
    learning_rate=0.0002, beta_1=0.5, beta_2=0.9)
# Loss function
gan_loss = keras.losses.BinaryCrossentropy(from_logits=True)

# Callbacks
cbk = GANMonitor(num_img=NUM_TEMP_CLASSES, latent_dim=LATENT_DIM, norma=255)

# %%
for mode in ["A", "B", "C"]:
  # Istanziamento modello
  gan = DCGAN(discriminator=d_model, generator=g_model, regressor=r_model, 
              latent_dim=LATENT_DIM, mode=mode)

  # Compilazione
  gan.compile(d_optimizer=discriminator_optimizer,
      g_optimizer=generator_optimizer,
      loss_fn=gan_loss,
  )

  gan.fit(dataset, epochs=100, batch_size=64, callbacks=[cbk]) 
  # 300 è troppo ma sicuro funziona
gan.fit(dataset, epochs=500, batch_size=64, callbacks=[cbk])
# Out:
# Epoch 1/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5658 - g_loss: 0.6259
# Epoch 2/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5214 - g_loss: 0.6864
# Epoch 3/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5272 - g_loss: 0.6747
# Epoch 4/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5352 - g_loss: 0.6781
# Epoch 5/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5127 - g_loss: 0.6857
# Epoch 6/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5274 - g_loss: 0.6840
# Epoch 7/100
# 157/157 [==============================] - 21s 136ms/step - d_loss: 0.5601 - g_loss: 0.6531
# Epoch 8/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5351 - g_loss: 0.6718
# Epoch 9/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5461 - g_loss: 0.6637
# Epoch 10/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5448 - g_loss: 0.6646
# Epoch 11/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5457 - g_loss: 0.6633
# Epoch 12/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5423 - g_loss: 0.6709
# Epoch 13/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5444 - g_loss: 0.6712
# Epoch 14/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5439 - g_loss: 0.6742
# Epoch 15/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5505 - g_loss: 0.6574
# Epoch 16/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5547 - g_loss: 0.6433
# Epoch 17/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5498 - g_loss: 0.6497
# Epoch 18/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5487 - g_loss: 0.6441
# Epoch 19/100
# 157/157 [==============================] - 2s 16ms/step - d_loss: 0.5524 - g_loss: 0.6417
# Epoch 20/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5492 - g_loss: 0.6457
# Epoch 21/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5550 - g_loss: 0.6459
# Epoch 22/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5531 - g_loss: 0.6324
# Epoch 23/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5579 - g_loss: 0.6283
# Epoch 24/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5543 - g_loss: 0.6337
# Epoch 25/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5565 - g_loss: 0.6310
# Epoch 26/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5541 - g_loss: 0.6385
# Epoch 27/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5538 - g_loss: 0.6400
# Epoch 28/100
# 157/157 [==============================] - 2s 14ms/step - d_loss: 0.5497 - g_loss: 0.6409
# Epoch 29/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5497 - g_loss: 0.6386
# Epoch 30/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5494 - g_loss: 0.6400
# Epoch 31/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5482 - g_loss: 0.6396
# Epoch 32/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5479 - g_loss: 0.6359
# Epoch 33/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5484 - g_loss: 0.6360
# Epoch 34/100
# 157/157 [==============================] - 3s 17ms/step - d_loss: 0.5459 - g_loss: 0.6465
# Epoch 35/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5431 - g_loss: 0.6465
# Epoch 36/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5431 - g_loss: 0.6465
# Epoch 37/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5408 - g_loss: 0.6505
# Epoch 38/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5432 - g_loss: 0.6467
# Epoch 39/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5420 - g_loss: 0.6503
# Epoch 40/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5398 - g_loss: 0.6496
# Epoch 41/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5406 - g_loss: 0.6542
# Epoch 42/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5377 - g_loss: 0.6554
# Epoch 43/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5395 - g_loss: 0.6548
# Epoch 44/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5387 - g_loss: 0.6548
# Epoch 45/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5397 - g_loss: 0.6554
# Epoch 46/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5398 - g_loss: 0.6544
# Epoch 47/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5392 - g_loss: 0.6533
# Epoch 48/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5399 - g_loss: 0.6526
# Epoch 49/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5399 - g_loss: 0.6557
# Epoch 50/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5414 - g_loss: 0.6522
# Epoch 51/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5423 - g_loss: 0.6524
# Epoch 52/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5400 - g_loss: 0.6602
# Epoch 53/100
# 157/157 [==============================] - 3s 18ms/step - d_loss: 0.5385 - g_loss: 0.6622
# Epoch 54/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5400 - g_loss: 0.6597
# Epoch 55/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5430 - g_loss: 0.6563
# Epoch 56/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5474 - g_loss: 0.6587
# Epoch 57/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5456 - g_loss: 0.6563
# Epoch 58/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5449 - g_loss: 0.6567
# Epoch 59/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5494 - g_loss: 0.6542
# Epoch 60/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5483 - g_loss: 0.6580
# Epoch 61/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5491 - g_loss: 0.6528
# Epoch 62/100
# 157/157 [==============================] - 2s 14ms/step - d_loss: 0.5453 - g_loss: 0.6574
# Epoch 63/100
# 157/157 [==============================] - 2s 14ms/step - d_loss: 0.5469 - g_loss: 0.6585
# Epoch 64/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5498 - g_loss: 0.6584
# Epoch 65/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5471 - g_loss: 0.6599
# Epoch 66/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5433 - g_loss: 0.6664
# Epoch 67/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5455 - g_loss: 0.6640
# Epoch 68/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5471 - g_loss: 0.6618
# Epoch 69/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5442 - g_loss: 0.6625
# Epoch 70/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5622 - g_loss: 0.6513
# Epoch 71/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5576 - g_loss: 0.6508
# Epoch 72/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5569 - g_loss: 0.6548
# Epoch 73/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5526 - g_loss: 0.6578
# Epoch 74/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5504 - g_loss: 0.6632
# Epoch 75/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5503 - g_loss: 0.6624
# Epoch 76/100
# 157/157 [==============================] - 3s 19ms/step - d_loss: 0.5549 - g_loss: 0.6587
# Epoch 77/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5568 - g_loss: 0.6553
# Epoch 78/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5588 - g_loss: 0.6599
# Epoch 79/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5527 - g_loss: 0.6613
# Epoch 80/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5543 - g_loss: 0.6599
# Epoch 81/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5603 - g_loss: 0.6532
# Epoch 82/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5590 - g_loss: 0.6559
# Epoch 83/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5546 - g_loss: 0.6606
# Epoch 84/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5556 - g_loss: 0.6617
# Epoch 85/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5573 - g_loss: 0.6623
# Epoch 86/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5599 - g_loss: 0.6579
# Epoch 87/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5726 - g_loss: 0.6449
# Epoch 88/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5555 - g_loss: 0.6614
# Epoch 89/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5582 - g_loss: 0.6599
# Epoch 90/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5648 - g_loss: 0.6519
# Epoch 91/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5516 - g_loss: 0.6651
# Epoch 92/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5508 - g_loss: 0.6643
# Epoch 93/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5612 - g_loss: 0.6558
# Epoch 94/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5699 - g_loss: 0.6474
# Epoch 95/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5607 - g_loss: 0.6583
# Epoch 96/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5545 - g_loss: 0.6658
# Epoch 97/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5554 - g_loss: 0.6641
# Epoch 98/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5553 - g_loss: 0.6593
# Epoch 99/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5577 - g_loss: 0.6608
# Epoch 100/100
# 157/157 [==============================] - 2s 13ms/step - d_loss: 0.5594 - g_loss: 0.6571
# Epoch 1/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6622 - g_loss: 0.6812
# Epoch 2/100
# 157/157 [==============================] - 2s 14ms/step - d_loss: 0.6592 - g_loss: 0.6767
# Epoch 3/100
# 157/157 [==============================] - 3s 22ms/step - d_loss: 0.6539 - g_loss: 0.6800
# Epoch 4/100
# 157/157 [==============================] - 2s 14ms/step - d_loss: 0.6505 - g_loss: 0.6793
# Epoch 5/100
# 157/157 [==============================] - 2s 14ms/step - d_loss: 0.6507 - g_loss: 0.6812
# Epoch 6/100
# 157/157 [==============================] - 2s 14ms/step - d_loss: 0.6504 - g_loss: 0.6788
# Epoch 7/100
# 157/157 [==============================] - 2s 14ms/step - d_loss: 0.6490 - g_loss: 0.6830
# Epoch 8/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6494 - g_loss: 0.6831
# Epoch 9/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6454 - g_loss: 0.6825
# Epoch 10/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6465 - g_loss: 0.6802
# Epoch 11/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6469 - g_loss: 0.6808
# Epoch 12/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6488 - g_loss: 0.6825
# Epoch 13/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6478 - g_loss: 0.6818
# Epoch 14/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6453 - g_loss: 0.6809
# Epoch 15/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6451 - g_loss: 0.6791
# Epoch 16/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6462 - g_loss: 0.6809
# Epoch 17/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6464 - g_loss: 0.6790
# Epoch 18/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6464 - g_loss: 0.6820
# Epoch 19/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6462 - g_loss: 0.6821
# Epoch 20/100
# 157/157 [==============================] - 2s 14ms/step - d_loss: 0.6448 - g_loss: 0.6827
# Epoch 21/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6442 - g_loss: 0.6821
# Epoch 22/100
# 157/157 [==============================] - 2s 14ms/step - d_loss: 0.6460 - g_loss: 0.6787
# Epoch 23/100
# 157/157 [==============================] - 2s 14ms/step - d_loss: 0.6459 - g_loss: 0.6803
# Epoch 24/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6431 - g_loss: 0.6814
# Epoch 25/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6434 - g_loss: 0.6836
# Epoch 26/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6434 - g_loss: 0.6820
# Epoch 27/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6463 - g_loss: 0.6801
# Epoch 28/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6451 - g_loss: 0.6802
# Epoch 29/100
# 157/157 [==============================] - 2s 14ms/step - d_loss: 0.6446 - g_loss: 0.6824
# Epoch 30/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6431 - g_loss: 0.6816
# Epoch 31/100
# 157/157 [==============================] - 2s 14ms/step - d_loss: 0.6421 - g_loss: 0.6826
# Epoch 32/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6441 - g_loss: 0.6831
# Epoch 33/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6420 - g_loss: 0.6817
# Epoch 34/100
# 157/157 [==============================] - 2s 14ms/step - d_loss: 0.6420 - g_loss: 0.6816
# Epoch 35/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6438 - g_loss: 0.6816
# Epoch 36/100
# 157/157 [==============================] - 2s 14ms/step - d_loss: 0.6420 - g_loss: 0.6825
# Epoch 37/100
# 157/157 [==============================] - 2s 14ms/step - d_loss: 0.6410 - g_loss: 0.6804
# Epoch 38/100
# 157/157 [==============================] - 4s 24ms/step - d_loss: 0.6411 - g_loss: 0.6826
# Epoch 39/100
# 157/157 [==============================] - 2s 14ms/step - d_loss: 0.6405 - g_loss: 0.6825
# Epoch 40/100
# 157/157 [==============================] - 2s 14ms/step - d_loss: 0.6408 - g_loss: 0.6808
# Epoch 41/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6399 - g_loss: 0.6830
# Epoch 42/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6411 - g_loss: 0.6823
# Epoch 43/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6415 - g_loss: 0.6834
# Epoch 44/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6409 - g_loss: 0.6805
# Epoch 45/100
# 157/157 [==============================] - 2s 14ms/step - d_loss: 0.6415 - g_loss: 0.6802
# Epoch 46/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6403 - g_loss: 0.6823
# Epoch 47/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6409 - g_loss: 0.6814
# Epoch 48/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6400 - g_loss: 0.6792
# Epoch 49/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6391 - g_loss: 0.6812
# Epoch 50/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6383 - g_loss: 0.6842
# Epoch 51/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6387 - g_loss: 0.6816
# Epoch 52/100
# 157/157 [==============================] - 2s 14ms/step - d_loss: 0.6385 - g_loss: 0.6810
# Epoch 53/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6382 - g_loss: 0.6830
# Epoch 54/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6392 - g_loss: 0.6818
# Epoch 55/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6380 - g_loss: 0.6829
# Epoch 56/100
# 157/157 [==============================] - 2s 14ms/step - d_loss: 0.6377 - g_loss: 0.6831
# Epoch 57/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6360 - g_loss: 0.6834
# Epoch 58/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6377 - g_loss: 0.6833
# Epoch 59/100
# 157/157 [==============================] - 2s 14ms/step - d_loss: 0.6373 - g_loss: 0.6815
# Epoch 60/100
# 157/157 [==============================] - 2s 14ms/step - d_loss: 0.6361 - g_loss: 0.6831
# Epoch 61/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6373 - g_loss: 0.6843
# Epoch 62/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6382 - g_loss: 0.6826
# Epoch 63/100
# 157/157 [==============================] - 2s 14ms/step - d_loss: 0.6391 - g_loss: 0.6840
# Epoch 64/100
# 157/157 [==============================] - 2s 14ms/step - d_loss: 0.6373 - g_loss: 0.6837
# Epoch 65/100
# 157/157 [==============================] - 2s 14ms/step - d_loss: 0.6376 - g_loss: 0.6799
# Epoch 66/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6374 - g_loss: 0.6831
# Epoch 67/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6395 - g_loss: 0.6842
# Epoch 68/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6381 - g_loss: 0.6846
# Epoch 69/100
# 157/157 [==============================] - 2s 14ms/step - d_loss: 0.6351 - g_loss: 0.6838
# Epoch 70/100
# 157/157 [==============================] - 2s 14ms/step - d_loss: 0.6366 - g_loss: 0.6846
# Epoch 71/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6370 - g_loss: 0.6845
# Epoch 72/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6371 - g_loss: 0.6839
# Epoch 73/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6382 - g_loss: 0.6849
# Epoch 74/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6367 - g_loss: 0.6844
# Epoch 75/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6393 - g_loss: 0.6835
# Epoch 76/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6373 - g_loss: 0.6854
# Epoch 77/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6373 - g_loss: 0.6830
# Epoch 78/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6357 - g_loss: 0.6832
# Epoch 79/100
# 157/157 [==============================] - 2s 14ms/step - d_loss: 0.6357 - g_loss: 0.6817
# Epoch 80/100
# 157/157 [==============================] - 2s 14ms/step - d_loss: 0.6371 - g_loss: 0.6832
# Epoch 81/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6385 - g_loss: 0.6848
# Epoch 82/100
# 157/157 [==============================] - 4s 27ms/step - d_loss: 0.6390 - g_loss: 0.6827
# Epoch 83/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6365 - g_loss: 0.6818
# Epoch 84/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6366 - g_loss: 0.6837
# Epoch 85/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6355 - g_loss: 0.6840
# Epoch 86/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6342 - g_loss: 0.6832
# Epoch 87/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6373 - g_loss: 0.6840
# Epoch 88/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6358 - g_loss: 0.6859
# Epoch 89/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6358 - g_loss: 0.6838
# Epoch 90/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6364 - g_loss: 0.6840
# Epoch 91/100
# 157/157 [==============================] - 2s 14ms/step - d_loss: 0.6355 - g_loss: 0.6826
# Epoch 92/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6366 - g_loss: 0.6809
# Epoch 93/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6351 - g_loss: 0.6840
# Epoch 94/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6352 - g_loss: 0.6824
# Epoch 95/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6340 - g_loss: 0.6834
# Epoch 96/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6335 - g_loss: 0.6824
# Epoch 97/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6358 - g_loss: 0.6829
# Epoch 98/100
# 157/157 [==============================] - 2s 14ms/step - d_loss: 0.6328 - g_loss: 0.6815
# Epoch 99/100
# 157/157 [==============================] - 2s 14ms/step - d_loss: 0.6338 - g_loss: 0.6835
# Epoch 100/100
# 157/157 [==============================] - 2s 14ms/step - d_loss: 0.6345 - g_loss: 0.6826
# Epoch 1/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6301 - g_loss: 0.6633
# Epoch 2/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6263 - g_loss: 0.6532
# Epoch 3/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6228 - g_loss: 0.6527
# Epoch 4/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6246 - g_loss: 0.6485
# Epoch 5/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6234 - g_loss: 0.6529
# Epoch 6/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6247 - g_loss: 0.6483
# Epoch 7/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6221 - g_loss: 0.6479
# Epoch 8/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6225 - g_loss: 0.6487
# Epoch 9/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6222 - g_loss: 0.6466
# Epoch 10/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6224 - g_loss: 0.6482
# Epoch 11/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6215 - g_loss: 0.6480
# Epoch 12/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6199 - g_loss: 0.6459
# Epoch 13/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6211 - g_loss: 0.6490
# Epoch 14/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6194 - g_loss: 0.6440
# Epoch 15/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6206 - g_loss: 0.6422
# Epoch 16/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6191 - g_loss: 0.6487
# Epoch 17/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6214 - g_loss: 0.6450
# Epoch 18/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6209 - g_loss: 0.6448
# Epoch 19/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6205 - g_loss: 0.6423
# Epoch 20/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6200 - g_loss: 0.6438
# Epoch 21/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6215 - g_loss: 0.6442
# Epoch 22/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6205 - g_loss: 0.6424
# Epoch 23/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6198 - g_loss: 0.6400
# Epoch 24/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6223 - g_loss: 0.6427
# Epoch 25/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6196 - g_loss: 0.6419
# Epoch 26/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6210 - g_loss: 0.6402
# Epoch 27/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6191 - g_loss: 0.6410
# Epoch 28/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6209 - g_loss: 0.6415
# Epoch 29/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6210 - g_loss: 0.6395
# Epoch 30/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6215 - g_loss: 0.6394
# Epoch 31/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6229 - g_loss: 0.6373
# Epoch 32/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6201 - g_loss: 0.6371
# Epoch 33/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6188 - g_loss: 0.6339
# Epoch 34/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6196 - g_loss: 0.6341
# Epoch 35/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6168 - g_loss: 0.6364
# Epoch 36/100
# 157/157 [==============================] - 5s 30ms/step - d_loss: 0.6199 - g_loss: 0.6346
# Epoch 37/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6181 - g_loss: 0.6336
# Epoch 38/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6194 - g_loss: 0.6320
# Epoch 39/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6209 - g_loss: 0.6344
# Epoch 40/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6196 - g_loss: 0.6316
# Epoch 41/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6193 - g_loss: 0.6303
# Epoch 42/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6179 - g_loss: 0.6295
# Epoch 43/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6187 - g_loss: 0.6303
# Epoch 44/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6195 - g_loss: 0.6305
# Epoch 45/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6186 - g_loss: 0.6267
# Epoch 46/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6181 - g_loss: 0.6271
# Epoch 47/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6185 - g_loss: 0.6254
# Epoch 48/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6190 - g_loss: 0.6274
# Epoch 49/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6179 - g_loss: 0.6269
# Epoch 50/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6171 - g_loss: 0.6259
# Epoch 51/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6179 - g_loss: 0.6254
# Epoch 52/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6174 - g_loss: 0.6256
# Epoch 53/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6175 - g_loss: 0.6291
# Epoch 54/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6172 - g_loss: 0.6223
# Epoch 55/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6171 - g_loss: 0.6240
# Epoch 56/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6171 - g_loss: 0.6222
# Epoch 57/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6158 - g_loss: 0.6142
# Epoch 58/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6168 - g_loss: 0.6145
# Epoch 59/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6166 - g_loss: 0.6169
# Epoch 60/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6166 - g_loss: 0.6136
# Epoch 61/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6168 - g_loss: 0.6127
# Epoch 62/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6163 - g_loss: 0.6116
# Epoch 63/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6164 - g_loss: 0.6099
# Epoch 64/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6167 - g_loss: 0.6096
# Epoch 65/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6152 - g_loss: 0.6083
# Epoch 66/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6143 - g_loss: 0.6036
# Epoch 67/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6161 - g_loss: 0.6095
# Epoch 68/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6174 - g_loss: 0.6037
# Epoch 69/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6174 - g_loss: 0.6087
# Epoch 70/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6152 - g_loss: 0.6056
# Epoch 71/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6164 - g_loss: 0.6096
# Epoch 72/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6164 - g_loss: 0.6074
# Epoch 73/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6144 - g_loss: 0.6067
# Epoch 74/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6157 - g_loss: 0.6076
# Epoch 75/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6158 - g_loss: 0.6064
# Epoch 76/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6133 - g_loss: 0.6061
# Epoch 77/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6158 - g_loss: 0.6056
# Epoch 78/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6154 - g_loss: 0.5966
# Epoch 79/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6149 - g_loss: 0.6034
# Epoch 80/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6169 - g_loss: 0.5993
# Epoch 81/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6155 - g_loss: 0.6011
# Epoch 82/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6154 - g_loss: 0.6011
# Epoch 83/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6138 - g_loss: 0.6024
# Epoch 84/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6148 - g_loss: 0.5991
# Epoch 85/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6149 - g_loss: 0.5944
# Epoch 86/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6155 - g_loss: 0.5996
# Epoch 87/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6174 - g_loss: 0.6015
# Epoch 88/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6163 - g_loss: 0.5979
# Epoch 89/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6146 - g_loss: 0.5945
# Epoch 90/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6154 - g_loss: 0.5949
# Epoch 91/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6165 - g_loss: 0.5936
# Epoch 92/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6164 - g_loss: 0.5957
# Epoch 93/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6146 - g_loss: 0.5932
# Epoch 94/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6143 - g_loss: 0.5902
# Epoch 95/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6164 - g_loss: 0.5916
# Epoch 96/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6159 - g_loss: 0.5909
# Epoch 97/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6151 - g_loss: 0.5859
# Epoch 98/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6144 - g_loss: 0.5857
# Epoch 99/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6140 - g_loss: 0.5781
# Epoch 100/100
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6151 - g_loss: 0.5688
# Epoch 1/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6152 - g_loss: 0.5678
# Epoch 2/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6154 - g_loss: 0.5570
# Epoch 3/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6143 - g_loss: 0.5556
# Epoch 4/500
# 157/157 [==============================] - 5s 34ms/step - d_loss: 0.6148 - g_loss: 0.5523
# Epoch 5/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6144 - g_loss: 0.5534
# Epoch 6/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6138 - g_loss: 0.5511
# Epoch 7/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6141 - g_loss: 0.5464
# Epoch 8/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6122 - g_loss: 0.5380
# Epoch 9/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6122 - g_loss: 0.5386
# Epoch 10/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6123 - g_loss: 0.5344
# Epoch 11/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6147 - g_loss: 0.5299
# Epoch 12/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6121 - g_loss: 0.5252
# Epoch 13/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6141 - g_loss: 0.5235
# Epoch 14/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6128 - g_loss: 0.5217
# Epoch 15/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6138 - g_loss: 0.5246
# Epoch 16/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6134 - g_loss: 0.5227
# Epoch 17/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6133 - g_loss: 0.5208
# Epoch 18/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6133 - g_loss: 0.5193
# Epoch 19/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6123 - g_loss: 0.5162
# Epoch 20/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6113 - g_loss: 0.5173
# Epoch 21/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6129 - g_loss: 0.5129
# Epoch 22/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6116 - g_loss: 0.5125
# Epoch 23/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6137 - g_loss: 0.5125
# Epoch 24/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6126 - g_loss: 0.5099
# Epoch 25/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6123 - g_loss: 0.5124
# Epoch 26/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6102 - g_loss: 0.5111
# Epoch 27/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6111 - g_loss: 0.5095
# Epoch 28/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6110 - g_loss: 0.5080
# Epoch 29/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6106 - g_loss: 0.5112
# Epoch 30/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6100 - g_loss: 0.5092
# Epoch 31/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6112 - g_loss: 0.5081
# Epoch 32/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6129 - g_loss: 0.5103
# Epoch 33/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6098 - g_loss: 0.5090
# Epoch 34/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6113 - g_loss: 0.5093
# Epoch 35/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6092 - g_loss: 0.5053
# Epoch 36/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6109 - g_loss: 0.5046
# Epoch 37/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6109 - g_loss: 0.5049
# Epoch 38/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6119 - g_loss: 0.5056
# Epoch 39/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6095 - g_loss: 0.5061
# Epoch 40/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6120 - g_loss: 0.5040
# Epoch 41/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6108 - g_loss: 0.5077
# Epoch 42/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6085 - g_loss: 0.5062
# Epoch 43/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6106 - g_loss: 0.5069
# Epoch 44/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6093 - g_loss: 0.5054
# Epoch 45/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6104 - g_loss: 0.5058
# Epoch 46/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6117 - g_loss: 0.5047
# Epoch 47/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6102 - g_loss: 0.5048
# Epoch 48/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6104 - g_loss: 0.5023
# Epoch 49/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6112 - g_loss: 0.5030
# Epoch 50/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6108 - g_loss: 0.5034
# Epoch 51/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6102 - g_loss: 0.5042
# Epoch 52/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6109 - g_loss: 0.5010
# Epoch 53/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6103 - g_loss: 0.5020
# Epoch 54/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6109 - g_loss: 0.5064
# Epoch 55/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6090 - g_loss: 0.5025
# Epoch 56/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6101 - g_loss: 0.5002
# Epoch 57/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6107 - g_loss: 0.5041
# Epoch 58/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6114 - g_loss: 0.4978
# Epoch 59/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6114 - g_loss: 0.5017
# Epoch 60/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6095 - g_loss: 0.5010
# Epoch 61/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6106 - g_loss: 0.5067
# Epoch 62/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6094 - g_loss: 0.5025
# Epoch 63/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6110 - g_loss: 0.5005
# Epoch 64/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6114 - g_loss: 0.5030
# Epoch 65/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6109 - g_loss: 0.5004
# Epoch 66/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6093 - g_loss: 0.5044
# Epoch 67/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6103 - g_loss: 0.4979
# Epoch 68/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6120 - g_loss: 0.5028
# Epoch 69/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6099 - g_loss: 0.5039
# Epoch 70/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6105 - g_loss: 0.5026
# Epoch 71/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6103 - g_loss: 0.5029
# Epoch 72/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6101 - g_loss: 0.5022
# Epoch 73/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6098 - g_loss: 0.5029
# Epoch 74/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6091 - g_loss: 0.4985
# Epoch 75/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6092 - g_loss: 0.4982
# Epoch 76/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6108 - g_loss: 0.4988
# Epoch 77/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6098 - g_loss: 0.5028
# Epoch 78/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6084 - g_loss: 0.5014
# Epoch 79/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6094 - g_loss: 0.4985
# Epoch 80/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6079 - g_loss: 0.5034
# Epoch 81/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6085 - g_loss: 0.4998
# Epoch 82/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6110 - g_loss: 0.4992
# Epoch 83/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6088 - g_loss: 0.4985
# Epoch 84/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6092 - g_loss: 0.5008
# Epoch 85/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6087 - g_loss: 0.5001
# Epoch 86/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6077 - g_loss: 0.5034
# Epoch 87/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6089 - g_loss: 0.4972
# Epoch 88/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6094 - g_loss: 0.4958
# Epoch 89/500
# 157/157 [==============================] - 6s 40ms/step - d_loss: 0.6079 - g_loss: 0.4993
# Epoch 90/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6085 - g_loss: 0.4962
# Epoch 91/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6090 - g_loss: 0.5014
# Epoch 92/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6086 - g_loss: 0.4954
# Epoch 93/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6074 - g_loss: 0.5003
# Epoch 94/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6091 - g_loss: 0.4949
# Epoch 95/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6085 - g_loss: 0.4930
# Epoch 96/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6086 - g_loss: 0.4952
# Epoch 97/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6077 - g_loss: 0.4973
# Epoch 98/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6078 - g_loss: 0.4998
# Epoch 99/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6076 - g_loss: 0.4982
# Epoch 100/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6084 - g_loss: 0.4970
# Epoch 101/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6073 - g_loss: 0.4923
# Epoch 102/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6089 - g_loss: 0.4963
# Epoch 103/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6078 - g_loss: 0.4937
# Epoch 104/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6071 - g_loss: 0.4915
# Epoch 105/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6078 - g_loss: 0.4948
# Epoch 106/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6066 - g_loss: 0.4935
# Epoch 107/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6073 - g_loss: 0.4899
# Epoch 108/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6070 - g_loss: 0.4907
# Epoch 109/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6083 - g_loss: 0.4946
# Epoch 110/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6091 - g_loss: 0.4949
# Epoch 111/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6102 - g_loss: 0.4934
# Epoch 112/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6080 - g_loss: 0.4918
# Epoch 113/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6085 - g_loss: 0.4978
# Epoch 114/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6075 - g_loss: 0.4942
# Epoch 115/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6071 - g_loss: 0.4933
# Epoch 116/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6057 - g_loss: 0.4929
# Epoch 117/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6084 - g_loss: 0.4912
# Epoch 118/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6070 - g_loss: 0.4940
# Epoch 119/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6072 - g_loss: 0.4902
# Epoch 120/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6075 - g_loss: 0.4947
# Epoch 121/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6075 - g_loss: 0.4887
# Epoch 122/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6061 - g_loss: 0.4921
# Epoch 123/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6071 - g_loss: 0.4924
# Epoch 124/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6090 - g_loss: 0.4944
# Epoch 125/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6063 - g_loss: 0.4939
# Epoch 126/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6072 - g_loss: 0.4902
# Epoch 127/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6079 - g_loss: 0.4858
# Epoch 128/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6071 - g_loss: 0.4906
# Epoch 129/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6068 - g_loss: 0.4876
# Epoch 130/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6070 - g_loss: 0.4902
# Epoch 131/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6087 - g_loss: 0.4902
# Epoch 132/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6067 - g_loss: 0.4880
# Epoch 133/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6058 - g_loss: 0.4873
# Epoch 134/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6068 - g_loss: 0.4898
# Epoch 135/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6079 - g_loss: 0.4897
# Epoch 136/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6067 - g_loss: 0.4938
# Epoch 137/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6067 - g_loss: 0.4864
# Epoch 138/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6072 - g_loss: 0.4850
# Epoch 139/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6071 - g_loss: 0.4899
# Epoch 140/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6082 - g_loss: 0.4898
# Epoch 141/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6069 - g_loss: 0.4944
# Epoch 142/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6061 - g_loss: 0.4891
# Epoch 143/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6084 - g_loss: 0.4884
# Epoch 144/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6074 - g_loss: 0.4885
# Epoch 145/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6062 - g_loss: 0.4915
# Epoch 146/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6063 - g_loss: 0.4902
# Epoch 147/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6050 - g_loss: 0.4879
# Epoch 148/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6065 - g_loss: 0.4847
# Epoch 149/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6069 - g_loss: 0.4896
# Epoch 150/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6076 - g_loss: 0.4941
# Epoch 151/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6071 - g_loss: 0.4881
# Epoch 152/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6078 - g_loss: 0.4923
# Epoch 153/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6066 - g_loss: 0.4877
# Epoch 154/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6062 - g_loss: 0.4896
# Epoch 155/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6057 - g_loss: 0.4903
# Epoch 156/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6057 - g_loss: 0.4842
# Epoch 157/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6069 - g_loss: 0.4876
# Epoch 158/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6060 - g_loss: 0.4910
# Epoch 159/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6061 - g_loss: 0.4903
# Epoch 160/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6072 - g_loss: 0.4900
# Epoch 161/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6056 - g_loss: 0.4879
# Epoch 162/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6066 - g_loss: 0.4879
# Epoch 163/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6068 - g_loss: 0.4890
# Epoch 164/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6056 - g_loss: 0.4857
# Epoch 165/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6060 - g_loss: 0.4859
# Epoch 166/500
# ...
# Epoch 348/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6050 - g_loss: 0.4827
# Epoch 349/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6050 - g_loss: 0.4918
# Epoch 350/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6034 - g_loss: 0.4874
# Epoch 351/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6047 - g_loss: 0.4857
# Epoch 352/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6037 - g_loss: 0.4859
# Epoch 353/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6045 - g_loss: 0.4849
# Epoch 354/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6027 - g_loss: 0.4862
# Epoch 355/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6055 - g_loss: 0.4862
# Epoch 356/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6049 - g_loss: 0.4845
# Epoch 357/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6045 - g_loss: 0.4863
# Epoch 358/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6044 - g_loss: 0.4882
# Epoch 359/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6042 - g_loss: 0.4869
# Epoch 360/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6041 - g_loss: 0.4835
# Epoch 361/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6043 - g_loss: 0.4841
# Epoch 362/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6047 - g_loss: 0.4858
# Epoch 363/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6046 - g_loss: 0.4900
# Epoch 364/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6040 - g_loss: 0.4914
# Epoch 365/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6037 - g_loss: 0.4870
# Epoch 366/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6040 - g_loss: 0.4874
# Epoch 367/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6027 - g_loss: 0.4888
# Epoch 368/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6049 - g_loss: 0.4862
# Epoch 369/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6056 - g_loss: 0.4832
# Epoch 370/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6045 - g_loss: 0.4882
# Epoch 371/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6032 - g_loss: 0.4858
# Epoch 372/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6029 - g_loss: 0.4845
# Epoch 373/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6044 - g_loss: 0.4863
# Epoch 374/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6034 - g_loss: 0.4891
# Epoch 375/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6047 - g_loss: 0.4822
# Epoch 376/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6042 - g_loss: 0.4856
# Epoch 377/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6028 - g_loss: 0.4862
# Epoch 378/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6041 - g_loss: 0.4855
# Epoch 379/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6053 - g_loss: 0.4851
# Epoch 380/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6047 - g_loss: 0.4878
# Epoch 381/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6021 - g_loss: 0.4818
# Epoch 382/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6033 - g_loss: 0.4866
# Epoch 383/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6044 - g_loss: 0.4845
# Epoch 384/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6050 - g_loss: 0.4849
# Epoch 385/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6030 - g_loss: 0.4875
# Epoch 386/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6031 - g_loss: 0.4858
# Epoch 387/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6043 - g_loss: 0.4838
# Epoch 388/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6036 - g_loss: 0.4836
# Epoch 389/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6048 - g_loss: 0.4882
# Epoch 390/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6051 - g_loss: 0.4856
# Epoch 391/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6046 - g_loss: 0.4846
# Epoch 392/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6030 - g_loss: 0.4886
# Epoch 393/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6034 - g_loss: 0.4867
# Epoch 394/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6064 - g_loss: 0.4862
# Epoch 395/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6036 - g_loss: 0.4851
# Epoch 396/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6029 - g_loss: 0.4869
# Epoch 397/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6029 - g_loss: 0.4855
# Epoch 398/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6056 - g_loss: 0.4890
# Epoch 399/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6037 - g_loss: 0.4856
# Epoch 400/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6030 - g_loss: 0.4854
# Epoch 401/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6046 - g_loss: 0.4866
# Epoch 402/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6027 - g_loss: 0.4858
# Epoch 403/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6047 - g_loss: 0.4843
# Epoch 404/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6031 - g_loss: 0.4872
# Epoch 405/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6048 - g_loss: 0.4865
# Epoch 406/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6019 - g_loss: 0.4895
# Epoch 407/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6025 - g_loss: 0.4843
# Epoch 408/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6029 - g_loss: 0.4846
# Epoch 409/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6029 - g_loss: 0.4856
# Epoch 410/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6051 - g_loss: 0.4880
# Epoch 411/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6045 - g_loss: 0.4846
# Epoch 412/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6041 - g_loss: 0.4898
# Epoch 413/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6046 - g_loss: 0.4888
# Epoch 414/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6026 - g_loss: 0.4841
# Epoch 415/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6043 - g_loss: 0.4860
# Epoch 416/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6035 - g_loss: 0.4880
# Epoch 417/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6044 - g_loss: 0.4855
# Epoch 418/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6034 - g_loss: 0.4887
# Epoch 419/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6028 - g_loss: 0.4852
# Epoch 420/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6042 - g_loss: 0.4861
# Epoch 421/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6036 - g_loss: 0.4831
# Epoch 422/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6057 - g_loss: 0.4859
# Epoch 423/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6031 - g_loss: 0.4874
# Epoch 424/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6043 - g_loss: 0.4833
# Epoch 425/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6048 - g_loss: 0.4847
# Epoch 426/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6048 - g_loss: 0.4856
# Epoch 427/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6046 - g_loss: 0.4886
# Epoch 428/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6046 - g_loss: 0.4855
# Epoch 429/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6029 - g_loss: 0.4888
# Epoch 430/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6029 - g_loss: 0.4872
# Epoch 431/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6041 - g_loss: 0.4851
# Epoch 432/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6036 - g_loss: 0.4887
# Epoch 433/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6048 - g_loss: 0.4881
# Epoch 434/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6041 - g_loss: 0.4882
# Epoch 435/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6052 - g_loss: 0.4841
# Epoch 436/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6040 - g_loss: 0.4857
# Epoch 437/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6036 - g_loss: 0.4901
# Epoch 438/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6033 - g_loss: 0.4854
# Epoch 439/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6043 - g_loss: 0.4883
# Epoch 440/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6039 - g_loss: 0.4835
# Epoch 441/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6037 - g_loss: 0.4842
# Epoch 442/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6027 - g_loss: 0.4874
# Epoch 443/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5994 - g_loss: 0.4749
# Epoch 444/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6001 - g_loss: 0.4751
# Epoch 445/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6008 - g_loss: 0.4701
# Epoch 446/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5997 - g_loss: 0.4713
# Epoch 447/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5997 - g_loss: 0.4686
# Epoch 448/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5996 - g_loss: 0.4750
# Epoch 449/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5984 - g_loss: 0.4732
# Epoch 450/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5978 - g_loss: 0.4740
# Epoch 451/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5992 - g_loss: 0.4704
# Epoch 452/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5992 - g_loss: 0.4707
# Epoch 453/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5981 - g_loss: 0.4699
# Epoch 454/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6000 - g_loss: 0.4699
# Epoch 455/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5973 - g_loss: 0.4682
# Epoch 456/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5997 - g_loss: 0.4701
# Epoch 457/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5999 - g_loss: 0.4666
# Epoch 458/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5988 - g_loss: 0.4695
# Epoch 459/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5983 - g_loss: 0.4674
# Epoch 460/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5985 - g_loss: 0.4683
# Epoch 461/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5988 - g_loss: 0.4717
# Epoch 462/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5995 - g_loss: 0.4695
# Epoch 463/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5991 - g_loss: 0.4679
# Epoch 464/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5980 - g_loss: 0.4676
# Epoch 465/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5992 - g_loss: 0.4676
# Epoch 466/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5986 - g_loss: 0.4684
# Epoch 467/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5997 - g_loss: 0.4675
# Epoch 468/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5988 - g_loss: 0.4689
# Epoch 469/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5971 - g_loss: 0.4682
# Epoch 470/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5988 - g_loss: 0.4693
# Epoch 471/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5990 - g_loss: 0.4676
# Epoch 472/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5992 - g_loss: 0.4704
# Epoch 473/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5969 - g_loss: 0.4613
# Epoch 474/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5991 - g_loss: 0.4658
# Epoch 475/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5987 - g_loss: 0.4659
# Epoch 476/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5985 - g_loss: 0.4697
# Epoch 477/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5988 - g_loss: 0.4655
# Epoch 478/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5985 - g_loss: 0.4657
# Epoch 479/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5979 - g_loss: 0.4681
# Epoch 480/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5986 - g_loss: 0.4707
# Epoch 481/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5990 - g_loss: 0.4658
# Epoch 482/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5981 - g_loss: 0.4661
# Epoch 483/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5980 - g_loss: 0.4681
# Epoch 484/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5985 - g_loss: 0.4675
# Epoch 485/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5977 - g_loss: 0.4686
# Epoch 486/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5989 - g_loss: 0.4688
# Epoch 487/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5987 - g_loss: 0.4691
# Epoch 488/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6000 - g_loss: 0.4696
# Epoch 489/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5986 - g_loss: 0.4702
# Epoch 490/500
# 157/157 [==============================] - 10s 65ms/step - d_loss: 0.5990 - g_loss: 0.4654
# Epoch 491/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.6009 - g_loss: 0.4687
# Epoch 492/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5989 - g_loss: 0.4696
# Epoch 493/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5978 - g_loss: 0.4682
# Epoch 494/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5985 - g_loss: 0.4668
# Epoch 495/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5970 - g_loss: 0.4675
# Epoch 496/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5974 - g_loss: 0.4694
# Epoch 497/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5993 - g_loss: 0.4673
# Epoch 498/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5973 - g_loss: 0.4695
# Epoch 499/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5989 - g_loss: 0.4689
# Epoch 500/500
# 157/157 [==============================] - 2s 15ms/step - d_loss: 0.5962 - g_loss: 0.4651

# %%
classes = tf.one_hot(range(NUM_TEMP_CLASSES), NUM_TEMP_CLASSES)
latent = tf.random.normal(shape=(NUM_TEMP_CLASSES, LATENT_DIM))
generated_images = gan.generator([classes, latent])
generated_images = generated_images
fig, axs = plt.subplots(1, NUM_TEMP_CLASSES, figsize=(17, 5))
for i in range(NUM_TEMP_CLASSES):
    img = generated_images[i].numpy().reshape(28, 28)
    axs[i].imshow(img)

# %% [markdown]
# Si vede come la progressione con la temperatura, almeno graficamente, è simile a quella attesa. Questo non vale per la prima classe, che probabilmente è mal posizionata.

# %%
classes = tf.one_hot(range(NUM_TEMP_CLASSES), NUM_TEMP_CLASSES)

fig, axs = plt.subplots(10, NUM_TEMP_CLASSES, figsize=(10, 10))
for i in range(10):
  for j in range(NUM_TEMP_CLASSES):
    latent = tf.random.normal(shape=(NUM_TEMP_CLASSES, LATENT_DIM))
    generated_images = gan.generator([classes, latent])
    generated_images = generated_images
    img = generated_images[j].numpy().reshape(28, 28)
    axs[i][j].imshow(img)
    axs[i][j].set(xticks=[], yticks=[])

# %%
d_model.save("discriminator.hdf5")
g_model.save("generator.hdf5")
r_model.save("regressor.hdf5")

# %%
# !wget https://github.com/raeubaen/ml/raw/master/dissertazione/generator.hdf5
gen = keras.models.load_model("generator.hdf5")

# %%
randint = np.random.randint(0, high=9, size=10000)
classes = tf.one_hot(randint, NUM_TEMP_CLASSES)

latent = tf.random.normal(shape=(10000, LATENT_DIM))
generated_images = gan.generator([classes, latent]).numpy().round()
'''
to_flip_ind = np.random.randint(0, len(generated_images), size=int(len(generated_images)/2))

up = generated_images==1
down = generated_images==-1
up[to_flip_ind, ...] = False
down[to_flip_ind, ...] = False

generated_images[up] = -1
generated_images[down] = 1
'''
# Out:
# '\nto_flip_ind = np.random.randint(0, len(generated_images), size=int(len(generated_images)/2))\n\nup = generated_images==1\ndown = generated_images==-1\nup[to_flip_ind, ...] = False\ndown[to_flip_ind, ...] = False\n\ngenerated_images[up] = -1\ngenerated_images[down] = 1\n'

# %%
magn = tf.reduce_mean(generated_images, axis=(1, 2))
plt.scatter(randint, magn)

# %%
orig_magn = tf.reduce_mean(conf, axis=(1,2))
plt.scatter(label, orig_magn)
